# %%
import pandas as pd
from statsmodels.tools.tools import add_constant
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.stattools import durbin_watson
from statsmodels.stats.outliers_influence import OLSInfluence
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso, LassoCV
from statsmodels.stats.anova import anova_lm

# %%
# Load dataset
df = pd.read_csv("Dataset/academic_meals_elementary_district.csv")

print("Original shape:", df.shape)
# Out:
# Original shape: (54, 263)

# %%
total_nulls = df.isnull().sum().sum()

print("Total missing values in dataset:", total_nulls)
# Out:
# Total missing values in dataset: 1

# %%
null_per_column = df.isnull().sum()

print(null_per_column)
# Out:
# District                         0
# ROE                              0
# student_disabilities_percent     1
# student_low_income_percent       0
# days_entered.x                   0
#                                 ..
# Science_Proficiency              0
# Science_Proficiency_LowIncome    0
# Science_Proficiency_CWD          0
# missing_frac                     0
# missing_count                    0
# Length: 263, dtype: int64

# %%
# Check which row has missing value
df[df["student_disabilities_percent"].isnull()]
# Out:
#             District   ROE  student_disabilities_percent  \
# 27  LOSTANT CUSD 425  35.0                           NaN
#
#     student_low_income_percent  days_entered.x  HEI 2015 Total Score  \
# 27                        26.8            21.0             67.000048
#
#     HEI 2015 Total Fruits (0-5)  HEI 2015 Whole Fruits (0-5)  \
# 27                          5.0                          5.0
#
#     HEI 2015 Total Vegetables (0-5)  HEI 2015 Greens and Beans (0-5)  ...  \
# 27                          2.93481                         3.043476  ...
#
#     ELA_Proficiency_LowIncome  ELA_Proficiency_CWD  Math_Proficiency  \
# 27                  60.558345            44.231892              30.8
#
#     Math_Proficiency_LowIncome  Math_Proficiency_CWD  Science_Proficiency  \
# 27                   27.499899             27.739182            42.316915
#
#     Science_Proficiency_LowIncome  Science_Proficiency_CWD  missing_frac  \
# 27                       40.73494                51.344596           0.7
#
#     missing_count
# 27            7.0
#
# [1 rows x 263 columns]

# %%
median_value = df["student_disabilities_percent"].median()

df["student_disabilities_percent"] = df["student_disabilities_percent"].fillna(median_value)

print("Missing after imputation:", df["student_disabilities_percent"].isnull().sum())
# Out:
# Missing after imputation: 0

# %%
cols_to_drop = [
    # Identifiers
    "ROE",
    
    # Tracking / merge artifacts
    "days_entered.x",
    "days_entered.y",
    "Day of Menu",
    
    # Metadata
    "Data Collected in NCC Database Version",
    "Data Collected in Software Version",
    "Data Generated in NCC Database Version",
    "Data Generated in Software Version",
    
    # Missing diagnostics 
    "missing_frac",
    "missing_count",

    "ELA_Proficiency_LowIncome",
    "ELA_Proficiency_CWD",
    "Math_Proficiency_LowIncome",
    "Math_Proficiency_CWD",
    "Science_Proficiency_LowIncome",
    "Science_Proficiency_CWD"
]

# %%
df_clean = df.drop(columns=[col for col in cols_to_drop if col in df.columns])

print("After removing non-analytical columns:", df_clean.shape)
# Out:
# After removing non-analytical columns: (54, 247)

# %%
removed = set(df.columns) - set(df_clean.columns)
print("Removed columns:")
print(removed)
# Out:
# Removed columns:
# {'ROE', 'Math_Proficiency_LowIncome', 'days_entered.x', 'Data Generated in NCC Database Version', 'days_entered.y', 'ELA_Proficiency_LowIncome', 'Math_Proficiency_CWD', 'Data Collected in NCC Database Version', 'Science_Proficiency_LowIncome', 'Data Collected in Software Version', 'Day of Menu', 'missing_frac', 'Data Generated in Software Version', 'ELA_Proficiency_CWD', 'missing_count', 'Science_Proficiency_CWD'}

# %%
# Identify columns ending with .x or .y
x_cols = [col for col in df_clean.columns if col.endswith(".x")]
y_cols = [col for col in df_clean.columns if col.endswith(".y")]

print("Columns ending with .x:", x_cols)
print("Columns ending with .y:", y_cols)
# Out:
# Columns ending with .x: ['% Calories from SFA.x', 'Total Saturated Fatty Acids (SFA) (g).x', 'Energy (kcal).x']
# Columns ending with .y: ['Energy (kcal).y', 'Total Saturated Fatty Acids (SFA) (g).y', '% Calories from SFA.y']

# %%
# Remove .x / .y Duplicate Columns 
cols_to_drop = []

for col in x_cols:
    base_name = col[:-2]  # remove ".x"
    y_version = base_name + ".y"
    
    if y_version in df_clean.columns:
        # If both exist, drop the .y version
        cols_to_drop.append(y_version)

df_clean = df_clean.drop(columns=cols_to_drop)

print("Removed duplicate .y columns")
print("New shape:", df_clean.shape)
# Out:
# Removed duplicate .y columns
# New shape: (54, 244)

# %%
# Remove EXACT Duplicate Columns (Same Values)
import numpy as np

duplicate_columns = []

for i in range(len(df_clean.columns)):
    for j in range(i + 1, len(df_clean.columns)):
        col1 = df_clean.columns[i]
        col2 = df_clean.columns[j]
        
        if df_clean[col1].equals(df_clean[col2]):
            duplicate_columns.append(col2)

# Remove duplicates
df_clean = df_clean.drop(columns=list(set(duplicate_columns)))

print("Exact duplicate columns removed:", duplicate_columns)
print("Shape after removing exact duplicates:", df_clean.shape)
# Out:
# Exact duplicate columns removed: ['Whole Grains (ounce equivalents)', 'Refined Grains (ounce equivalents)', 'Sucrose Polyester (g)', 'User Nutrient 1 (mg)', 'User Nutrient 2 (mg)', 'User Nutrient 3 (mg)', 'User Nutrient 4 (mg)', 'User Nutrient 5 (mg)', 'User Nutrient 6 (mg)', 'User Nutrient 7 (mg)', 'User Nutrient 8 (mg)', 'User Nutrient 9 (mg)', 'User Nutrient 10 (mg)', 'User Nutrient 11 (mg)', 'User Nutrient 12 (mg)', 'User Nutrient 13 (mg)', 'User Nutrient 14 (mg)', 'User Nutrient 15 (mg)', 'User Nutrient 16 (mg)', 'User Nutrient 17 (mg)', 'User Nutrient 18 (mg)', 'User Nutrient 19 (mg)', 'User Nutrient 20 (mg)', 'Sucralose (mg)', 'Isomalt (g)', 'Lactitol (g)', 'User Nutrient 1 (mg)', 'User Nutrient 2 (mg)', 'User Nutrient 3 (mg)', 'User Nutrient 4 (mg)', 'User Nutrient 5 (mg)', 'User Nutrient 6 (mg)', 'User Nutrient 7 (mg)', 'User Nutrient 8 (mg)', 'User Nutrient 9 (mg)', 'User Nutrient 10 (mg)', 'User Nutrient 11 (mg)', 'User Nutrient 12 (mg)', 'User Nutrient 13 (mg)', 'User Nutrient 14 (mg)', 'User Nutrient 15 (mg)', 'User Nutrient 16 (mg)', 'User Nutrient 17 (mg)', 'User Nutrient 18 (mg)', 'User Nutrient 19 (mg)', 'User Nutrient 20 (mg)', 'Sucralose (mg)', 'Isomalt (g)', 'Lactitol (g)', 'User Nutrient 2 (mg)', 'User Nutrient 3 (mg)', 'User Nutrient 4 (mg)', 'User Nutrient 5 (mg)', 'User Nutrient 6 (mg)', 'User Nutrient 7 (mg)', 'User Nutrient 8 (mg)', 'User Nutrient 9 (mg)', 'User Nutrient 10 (mg)', 'User Nutrient 11 (mg)', 'User Nutrient 12 (mg)', 'User Nutrient 13 (mg)', 'User Nutrient 14 (mg)', 'User Nutrient 15 (mg)', 'User Nutrient 16 (mg)', 'User Nutrient 17 (mg)', 'User Nutrient 18 (mg)', 'User Nutrient 19 (mg)', 'User Nutrient 20 (mg)', 'Sucralose (mg)', 'Isomalt (g)', 'Lactitol (g)', 'User Nutrient 3 (mg)', 'User Nutrient 4 (mg)', 'User Nutrient 5 (mg)', 'User Nutrient 6 (mg)', 'User Nutrient 7 (mg)', 'User Nutrient 8 (mg)', 'User Nutrient 9 (mg)', 'User Nutrient 10 (mg)', 'User Nutrient 11 (mg)', 'User Nutrient 12 (mg)', 'User Nutrient 13 (mg)', 'User Nutrient 14 (mg)', 'User Nutrient 15 (mg)', 'User Nutrient 16 (mg)', 'User Nutrient 17 (mg)', 'User Nutrient 18 (mg)', 'User Nutrient 19 (mg)', 'User Nutrient 20 (mg)', 'Sucralose (mg)', 'Isomalt (g)', 'Lactitol (g)', 'User Nutrient 4 (mg)', 'User Nutrient 5 (mg)', 'User Nutrient 6 (mg)', 'User Nutrient 7 (mg)', 'User Nutrient 8 (mg)', 'User Nutrient 9 (mg)', 'User Nutrient 10 (mg)', 'User Nutrient 11 (mg)', 'User Nutrient 12 (mg)', 'User Nutrient 13 (mg)', 'User Nutrient 14 (mg)', 'User Nutrient 15 (mg)', 'User Nutrient 16 (mg)', 'User Nutrient 17 (mg)', 'User Nutrient 18 (mg)', 'User Nutrient 19 (mg)', 'User Nutrient 20 (mg)', 'Sucralose (mg)', 'Isomalt (g)', 'Lactitol (g)', 'User Nutrient 5 (mg)', 'User Nutrient 6 (mg)', 'User Nutrient 7 (mg)', 'User Nutrient 8 (mg)', 'User Nutrient 9 (mg)', 'User Nutrient 10 (mg)', 'User Nutrient 11 (mg)', 'User Nutrient 12 (mg)', 'User Nutrient 13 (mg)', 'User Nutrient 14 (mg)', 'User Nutrient 15 (mg)', 'User Nutrient 16 (mg)', 'User Nutrient 17 (mg)', 'User Nutrient 18 (mg)', 'User Nutrient 19 (mg)', 'User Nutrient 20 (mg)', 'Sucralose (mg)', 'Isomalt (g)', 'Lactitol (g)', 'User Nutrient 6 (mg)', 'User Nutrient 7 (mg)', 'User Nutrient 8 (mg)', 'User Nutrient 9 (mg)', 'User Nutrient 10 (mg)', 'User Nutrient 11 (mg)', 'User Nutrient 12 (mg)', 'User Nutrient 13 (mg)', 'User Nutrient 14 (mg)', 'User Nutrient 15 (mg)', 'User Nutrient 16 (mg)', 'User Nutrient 17 (mg)', 'User Nutrient 18 (mg)', 'User Nutrient 19 (mg)', 'User Nutrient 20 (mg)', 'Sucralose (mg)', 'Isomalt (g)', 'Lactitol (g)', 'User Nutrient 7 (mg)', 'User Nutrient 8 (mg)', 'User Nutrient 9 (mg)', 'User Nutrient 10 (mg)', 'User Nutrient 11 (mg)', 'User Nutrient 12 (mg)', 'User Nutrient 13 (mg)', 'User Nutrient 14 (mg)', 'User Nutrient 15 (mg)', 'User Nutrient 16 (mg)', 'User Nutrient 17 (mg)', 'User Nutrient 18 (mg)', 'User Nutrient 19 (mg)', 'User Nutrient 20 (mg)', 'Sucralose (mg)', 'Isomalt (g)', 'Lactitol (g)', 'User Nutrient 8 (mg)', 'User Nutrient 9 (mg)', 'Us ...
# Shape after removing exact duplicates: (54, 218)

# %%
# Remove Duplicate Energy Columns
energy_cols = [col for col in df_clean.columns if "Energy" in col]
print("Energy-related columns:", energy_cols)
# Out:
# Energy-related columns: ['Energy (kcal).x', 'Energy (kj)']

# %%
if "Energy (kj)" in df_clean.columns:
    df_clean = df_clean.drop(columns=["Energy (kj)"])

# %%
print("Final shape after duplicate removal:", df_clean.shape)
# Out:
# Final shape after duplicate removal: (54, 217)

# %%
# Keep numeric columns only
df_numeric = df_clean.select_dtypes(include=[np.number])

print("Numeric shape:", df_numeric.shape)
# Out:
# Numeric shape: (54, 216)

# %%
variances = df_numeric.var()

# Look at smallest variances
variances.sort_values().head(10)
# Out:
# Saccharin (mg)                                     0.000000e+00
# Maltitol (g)                                       4.053150e-08
# Erythritol (g)                                     3.200367e-07
# PUFA 20:5 n-3 (eicosapentaenoic acid [EPA]) (g)    1.626067e-05
# Xylitol (g)                                        4.483152e-05
# CLA trans-10, cis-12 (g)                           4.506519e-05
# PUFA 22:5 n-3 (docosapentaenoic acid [DPA]) (g)    4.847515e-05
# % Calories from Alcohol                            7.560004e-05
# PUFA 18:4 (parinaric acid) (g)                     7.758662e-05
# PUFA 22:6 n-3 (docosahexaenoic acid [DHA]) (g)     8.634814e-05
# dtype: float64

# %%
from sklearn.feature_selection import VarianceThreshold

# Set small threshold
selector = VarianceThreshold(threshold=0.01)

X_reduced = selector.fit_transform(df_numeric)

# Get kept columns
kept_columns = df_numeric.columns[selector.get_support()]

# Create new cleaned dataframe
df_variance_clean = df_numeric[kept_columns]

print("Before variance filtering:", df_numeric.shape)
print("After variance filtering:", df_variance_clean.shape)
# Out:
# Before variance filtering: (54, 216)
# After variance filtering: (54, 191)

# %%
df_variance_clean.columns
# Out:
# Index(['student_disabilities_percent', 'student_low_income_percent',
#        'HEI 2015 Total Score', 'HEI 2015 Total Fruits (0-5)',
#        'HEI 2015 Whole Fruits (0-5)', 'HEI 2015 Total Vegetables (0-5)',
#        'HEI 2015 Greens and Beans (0-5)', 'HEI 2015 Whole Grains (0-10)',
#        'HEI 2015 Dairy (0-10)', 'HEI 2015 Total Protein Foods (0-5)',
#        ...
#        'Total Lignans (mcg)', 'Secoisolariciresinol (mcg)',
#        'Matairesinol (mcg)', 'Lariciresinol (mcg)', 'Pinoresinol (mcg)',
#        'PUFA 18:2 n-6 (linoleic acid [LA]) (g)', 'Omega-6 Fatty Acids (g)',
#        'ELA_Proficiency', 'Math_Proficiency', 'Science_Proficiency'],
#       dtype='object', length=191)

# %%
print(df_variance_clean.columns.tolist())
# Out:
# ['student_disabilities_percent', 'student_low_income_percent', 'HEI 2015 Total Score', 'HEI 2015 Total Fruits (0-5)', 'HEI 2015 Whole Fruits (0-5)', 'HEI 2015 Total Vegetables (0-5)', 'HEI 2015 Greens and Beans (0-5)', 'HEI 2015 Whole Grains (0-10)', 'HEI 2015 Dairy (0-10)', 'HEI 2015 Total Protein Foods (0-5)', 'HEI 2015 Seafood and Plant Proteins (0-5)', 'HEI 2015 Fatty Acids (0-10)', 'HEI 2015 Refined Grains (0-10)', 'HEI 2015 Sodium (0-10)', 'HEI 2015 Added Sugars (0-10)', 'HEI 2015 Saturated Fats (0-10)', 'Total Fruit Servings in cup equivalents per 1000 kcal', 'Whole Fruit Servings in cup equivalents per 1000 kcal', 'Total Vegetable Servings in cup equivalents per 1000 kcal', 'Greens and Beans Servings in cup equivalents per 1000 kcal', 'Whole Grain Servings in ounce equivalents per 1000 kcal', 'Dairy Servings in cup equivalents per 1000 kcal', 'Total Protein Servings in ounce equivalents per 1000 kcal', 'Seafood and Plant Protein Servings in ounce equivalents per 1000 kcal', 'Fatty Acids Ratio', 'Refined Grains in ounce equivalents per 1000 kcal', 'Sodium (g) per 1000 kcal', '% Calories from Added Sugars (by Total Sugars)', '% Calories from SFA.x', 'Total Fruit Servings in cup equivalents', 'Whole Fruit Servings in cup equivalents', 'Total Vegetable Servings in cup equivalents', 'Greens and Beans Servings in cup equivalents', 'Whole Grain Servings in ounce equivalents', 'Dairy Servings in cup equivalents', 'Total Protein Servings in ounce equivalents', 'Seafood and Plant Protein Servings in ounce equivalents', 'Total Polyunsaturated Fatty Acids (PUFA) (g) and Total Monounsaturated Fatty Acids (MUFA) (g)', 'Total Saturated Fatty Acids (SFA) (g).x', 'Refined Grains in ounce equivalents', 'Sodium (g)', 'Kcals from Added Sugars (by Total Sugars)', 'Kcals from Saturated Fats', 'Energy (kcal).x', 'Total Grams', 'Total Fat (g)', 'Total Carbohydrate (g)', 'Total Protein (g)', 'Animal Protein (g)', 'Vegetable Protein (g)', 'Cholesterol (mg)', 'Total Monounsaturated Fatty Acids (MUFA) (g)', 'Total Polyunsaturated Fatty Acids (PUFA) (g)', 'Fructose (g)', 'Galactose (g)', 'Glucose (g)', 'Lactose (g)', 'Maltose (g)', 'Sucrose (g)', 'Starch (g)', 'Total Dietary Fiber (g)', 'Soluble Dietary Fiber (g)', 'Insoluble Dietary Fiber (g)', 'Pectins (g)', 'Total Vitamin A Activity (International Units) (IU)', 'Beta-Carotene Equivalents (derived from provitamin A carotenoids) (mcg)', 'Retinol (mcg)', 'Vitamin D (calciferol) (mcg)', 'Total Alpha-Tocopherol Equivalents (mg)', 'Vitamin E (Total Alpha-Tocopherol) (mg)', 'Beta-Tocopherol (mg)', 'Gamma-Tocopherol (mg)', 'Delta-Tocopherol (mg)', 'Vitamin K (phylloquinone) (mcg)', 'Vitamin C (ascorbic acid) (mg)', 'Thiamin (vitamin B1) (mg)', 'Riboflavin (vitamin B2) (mg)', 'Niacin (vitamin B3) (mg)', 'Pantothenic Acid (mg)', 'Vitamin B-6 (pyridoxine, pyridoxyl, & pyridoxamine) (mg)', 'Total Folate (mcg)', 'Vitamin B-12 (cobalamin) (mcg)', 'Calcium (mg)', 'Phosphorus (mg)', 'Magnesium (mg)', 'Iron (mg)', 'Zinc (mg)', 'Copper (mg)', 'Selenium (mcg)', 'Sodium (mg)', 'Potassium (mg)', 'SFA 4:0 (butyric acid) (g)', 'SFA 6:0 (caproic acid) (g)', 'SFA 10:0 (capric acid) (g)', 'SFA 12:0 (lauric acid) (g)', 'SFA 14:0 (myristic acid) (g)', 'SFA 16:0 (palmitic acid) (g)', 'SFA 18:0 (stearic acid) (g)', 'SFA 22:0 (behenic acid) (g)', 'MUFA 16:1 (palmitoleic acid) (g)', 'MUFA 18:1 (oleic acid) (g)', 'MUFA 20:1 (gadoleic acid) (g)', 'PUFA 18:2 (linoleic acid, undifferentiated) (g)', 'PUFA 18:3 (linolenic acid, undifferentiated) (g)', 'Tryptophan (g)', 'Threonine (g)', 'Isoleucine (g)', 'Leucine (g)', 'Lysine (g)', 'Methionine (g)', 'Cystine (g)', 'Phenylalanine (g)', 'Tyrosine (g)', 'Valine (g)', 'Arginine (g)', 'Histidine (g)', 'Alanine (g)', 'Aspartic Acid (g)', 'Glutamic Acid (g)', 'Glycine (g)', 'Proline (g)', 'Serine (g)', 'Aspartame (mg)', 'Caffeine (mg)', 'Phytic Acid (mg)', 'Oxalic Acid (mg)', '3-Methylhistidine (mg)', 'Ash (g)', 'Water (g)', '% Calories from Fat', '% Calories from Carbohydrate', '% Calori ...

# %%
# Response variables
response_vars = [
    'ELA_Proficiency',
    'Math_Proficiency',
    'Science_Proficiency'
]

# SES variables
ses_vars = [
    'student_disabilities_percent',
    'student_low_income_percent'
]

# HEI total + HEI component score variables
hei_vars = [col for col in df_variance_clean.columns if col.startswith('HEI 2015')]

# Remaining nutrition variables
nutrition_vars = [
    col for col in df_variance_clean.columns
    if col not in response_vars + ses_vars + hei_vars
]

# %%
# Print counts
print("Number of response variables:", len(response_vars))
print("Number of SES variables:", len(ses_vars))
print("Number of HEI variables:", len(hei_vars))
print("Number of other nutrition variables:", len(nutrition_vars))
# Out:
# Number of response variables: 3
# Number of SES variables: 2
# Number of HEI variables: 14
# Number of other nutrition variables: 172

# %%
print("\nResponse variables:")
print(response_vars)

print("\nSES variables:")
print(ses_vars)

print("\nHEI variables:")
print(hei_vars)

print("\nFirst 20 other nutrition variables:")
print(nutrition_vars[:20])
# Out:
# Response variables:
# ['ELA_Proficiency', 'Math_Proficiency', 'Science_Proficiency']
#
# SES variables:
# ['student_disabilities_percent', 'student_low_income_percent']
#
# HEI variables:
# ['HEI 2015 Total Score', 'HEI 2015 Total Fruits (0-5)', 'HEI 2015 Whole Fruits (0-5)', 'HEI 2015 Total Vegetables (0-5)', 'HEI 2015 Greens and Beans (0-5)', 'HEI 2015 Whole Grains (0-10)', 'HEI 2015 Dairy (0-10)', 'HEI 2015 Total Protein Foods (0-5)', 'HEI 2015 Seafood and Plant Proteins (0-5)', 'HEI 2015 Fatty Acids (0-10)', 'HEI 2015 Refined Grains (0-10)', 'HEI 2015 Sodium (0-10)', 'HEI 2015 Added Sugars (0-10)', 'HEI 2015 Saturated Fats (0-10)']
#
# First 20 other nutrition variables:
# ['Total Fruit Servings in cup equivalents per 1000 kcal', 'Whole Fruit Servings in cup equivalents per 1000 kcal', 'Total Vegetable Servings in cup equivalents per 1000 kcal', 'Greens and Beans Servings in cup equivalents per 1000 kcal', 'Whole Grain Servings in ounce equivalents per 1000 kcal', 'Dairy Servings in cup equivalents per 1000 kcal', 'Total Protein Servings in ounce equivalents per 1000 kcal', 'Seafood and Plant Protein Servings in ounce equivalents per 1000 kcal', 'Fatty Acids Ratio', 'Refined Grains in ounce equivalents per 1000 kcal', 'Sodium (g) per 1000 kcal', '% Calories from Added Sugars (by Total Sugars)', '% Calories from SFA.x', 'Total Fruit Servings in cup equivalents', 'Whole Fruit Servings in cup equivalents', 'Total Vegetable Servings in cup equivalents', 'Greens and Beans Servings in cup equivalents', 'Whole Grain Servings in ounce equivalents', 'Dairy Servings in cup equivalents', 'Total Protein Servings in ounce equivalents']

# %% [markdown]
# ### MODEL 1: REMOVE MULTICOLLINEARIY & FIT OLS

# %%
# outcomes
outcomes = ['ELA_Proficiency', 'Math_Proficiency', 'Science_Proficiency']

# SES variables
ses_vars = [
    'student_low_income_percent',
    'student_disabilities_percent'
]

# nutrition candidate variables only
nutrition_vars = [
    col for col in df_variance_clean.columns
    if col not in outcomes + ses_vars
]

print("Number of nutrition variables:", len(nutrition_vars))
# Out:
# Number of nutrition variables: 186

# %%
nutrition_corr = df_variance_clean[nutrition_vars].corr().abs()
nutrition_corr.head()
# Out:
#                                  HEI 2015 Total Score  \
# HEI 2015 Total Score                         1.000000
# HEI 2015 Total Fruits (0-5)                  0.591346
# HEI 2015 Whole Fruits (0-5)                  0.670081
# HEI 2015 Total Vegetables (0-5)              0.112862
# HEI 2015 Greens and Beans (0-5)              0.371052
#
#                                  HEI 2015 Total Fruits (0-5)  \
# HEI 2015 Total Score                                0.591346
# HEI 2015 Total Fruits (0-5)                         1.000000
# HEI 2015 Whole Fruits (0-5)                         0.886485
# HEI 2015 Total Vegetables (0-5)                     0.198958
# HEI 2015 Greens and Beans (0-5)                     0.066154
#
#                                  HEI 2015 Whole Fruits (0-5)  \
# HEI 2015 Total Score                                0.670081
# HEI 2015 Total Fruits (0-5)                         0.886485
# HEI 2015 Whole Fruits (0-5)                         1.000000
# HEI 2015 Total Vegetables (0-5)                     0.256720
# HEI 2015 Greens and Beans (0-5)                     0.167618
#
#                                  HEI 2015 Total Vegetables (0-5)  \
# HEI 2015 Total Score                                    0.112862
# HEI 2015 Total Fruits (0-5)                             0.198958
# HEI 2015 Whole Fruits (0-5)                             0.256720
# HEI 2015 Total Vegetables (0-5)                         1.000000
# HEI 2015 Greens and Beans (0-5)                         0.624900
#
#                                  HEI 2015 Greens and Beans (0-5)  \
# HEI 2015 Total Score                                    0.371052
# HEI 2015 Total Fruits (0-5)                             0.066154
# HEI 2015 Whole Fruits (0-5)                             0.167618
# HEI 2015 Total Vegetables (0-5)                         0.624900
# HEI 2015 Greens and Beans (0-5)                         1.000000
#
#                                  HEI 2015 Whole Grains (0-10)  \
# HEI 2015 Total Score                                 0.267387
# HEI 2015 Total Fruits (0-5)                          0.133492
# HEI 2015 Whole Fruits (0-5)                          0.155783
# HEI 2015 Total Vegetables (0-5)                      0.562289
# HEI 2015 Greens and Beans (0-5)                      0.191071
#
#                                  HEI 2015 Dairy (0-10)  \
# HEI 2015 Total Score                          0.734048
# HEI 2015 Total Fruits (0-5)                   0.380807
# HEI 2015 Whole Fruits (0-5)                   0.405953
# HEI 2015 Total Vegetables (0-5)               0.001768
# HEI 2015 Greens and Beans (0-5)               0.190860
#
#                                  HEI 2015 Total Protein Foods (0-5)  \
# HEI 2015 Total Score                                       0.207044
# HEI 2015 Total Fruits (0-5)                                0.347066
# HEI 2015 Whole Fruits (0-5)                                0.271623
# HEI 2015 Total Vegetables (0-5)                            0.028265
# HEI 2015 Greens and Beans (0-5)                            0.089849
#
#                                  HEI 2015 Seafood and Plant Proteins (0-5)  \
# HEI 2015 Total Score                                              0.423870
# HEI 2015 Total Fruits (0-5)                                       0.186979
# HEI 2015 Whole Fruits (0-5)                                       0.034627
# HEI 2015 Total Vegetables (0-5)                                   0.117375
# HEI 2015 Greens and Beans (0-5)                                   0.233706
#
#                                  HEI 2015 Fatty Acids (0-10)  ...  \
# HEI 2015 Total Score                                0.012596  ...
# HEI 2015 Total Fruits (0-5)                         0.375366  ...
# HEI 2015 Whole Fruits (0-5)                         0.175860  ...
# HEI 2015 Total Vegetables (0-5)                     0.020168  ...
# HEI 2015 Greens and Beans (0-5)                     0.055540  ...
#
#                                  PUFA 18:3 n-3 (alpha-linolenic acid [ALA]) (g)  \
# HEI 2015 Total Score                                                   0.002370
# HEI 2015 Total Fruits (0-5)                                            0.199178
# HEI 2015 Whole Fruits (0-5)                                            0.173251
# HEI 2015 Total Vegetables (0-5)                                        0.204737
# HEI 2015 Greens and Beans (0-5)                                        0.058095
#
#                                  Solid Fats (g)  Gluten (g)  \
# HEI 2015 Total Score                   0.061689    0.029813
# HEI 2015 Total Fruits (0-5)            0.161632    0.341648
# HEI 2015 Whole Fruits (0-5)            0.170642    0.250714
# HEI 2015 Total Vegetables (0-5)        0.318338    0.427371
# HEI 2015 Greens and Beans (0-5)        0.074653    0.129551
#
#                                  Total Lignans (mcg)  \
# HEI 2015 Total Score                        0.427748
# HEI 2015 Total Fruits (0-5)                 0.011515
# HEI 2015 Whole Fruits (0-5)                 0.031415
# HEI 2015 Total Vegetables (0-5)             0.139576
# HEI 2015 Greens and Beans (0-5)             0.430834
#
#                                  Secoisolariciresinol (mcg)  \
# HEI 2015 Total Score                               0.251003
# HEI 2015 Total Fruits (0-5)                        0.143938
# HEI 2015 Whole Fruits (0-5)                        0.128312
# HEI 2015 Total Vegetables (0-5)                    0.039479
# HEI 2015 Greens and Beans (0-5)                    0.096459
#
#                                  Matairesinol (mcg)  Lariciresinol (mcg)  \
# HEI 2015 Total Score                       0.421996             0.526300
# HEI 2015 Total Fruits (0-5)                0.066014             0.023350
# HEI 2015 Whole Fruits (0-5)                0.043891             0.130364
# HEI 2015 Total Vegetables (0-5)            0.196885             0.003438
# HEI 2015 Greens and Beans (0-5)            0.098675             0.332343
#
#                                  Pinoresinol (mcg)  \
# HEI 2015 Total Score                      0.272211
# HEI 2015 Total Fruits (0-5)               0.156213
# HEI 2015 Whole Fruits (0-5)               0.110519
# HEI 2015 Total Vegetables (0-5)           0.207494
# HEI 2015 Greens and Beans (0-5)           0.500093
#
#                                  PUFA 18:2 n-6 (linoleic acid [LA]) (g)  \
# HEI 2015 Total Score                                           0.130630
# HEI 2015 Total Fruits (0-5)                                    0.194138
# HEI 2015 Whole Fruits (0-5)                                    0.129237
# HEI 2015 Total Vegetables (0-5)                                0.248981
# HEI 2015 Greens and Beans (0-5)                                0.075255
#
#                                  Omega-6 Fatty Acids (g)
# HEI 2015 Total Score                            0.129237
# HEI 2015 Total Fruits (0-5)                     0.193922
# HEI 2015 Whole Fruits (0-5)                     0.129562
# HEI 2015 Total Vegetables (0-5)                 0.249081
# HEI 2015 Greens and Beans (0-5)                 0.074691
#
# [5 rows x 186 columns]

# %%
threshold = 0.85

upper_triangle = nutrition_corr.where(
    np.triu(np.ones(nutrition_corr.shape), k=1).astype(bool)
)

high_corr_pairs = []

# %%
for col in upper_triangle.columns:
    for row in upper_triangle.index:
        corr_value = upper_triangle.loc[row, col]
        if pd.notna(corr_value) and corr_value > threshold:
            high_corr_pairs.append((row, col, corr_value))

# %%
high_corr_df = pd.DataFrame(high_corr_pairs, columns=['var1', 'var2', 'abs_correlation'])
high_corr_df = high_corr_df.sort_values('abs_correlation', ascending=False)

high_corr_df.head(30)
# Out:
#                                                   var1  \
# 2095                                    Aspartame (mg)
# 2441         Kcals from Added Sugars (by Total Sugars)
# 423                                         Sodium (g)
# 2283                 Glycemic Load (glucose reference)
# 2154                Glycemic Index (glucose reference)
# 2660            PUFA 18:2 n-6 (linoleic acid [LA]) (g)
# 20             Total Saturated Fatty Acids (SFA) (g).x
# 2075                                     Daidzein (mg)
# 2360                                 Total Protein (g)
# 2517  PUFA 18:3 (linolenic acid, undifferentiated) (g)
# 586       Total Monounsaturated Fatty Acids (MUFA) (g)
# 2518                           Omega-3 Fatty Acids (g)
# 2590   PUFA 18:2 (linoleic acid, undifferentiated) (g)
# 2637   PUFA 18:2 (linoleic acid, undifferentiated) (g)
# 1935  PUFA 18:3 (linolenic acid, undifferentiated) (g)
# 2100                            Total Carbohydrate (g)
# 1070                                       Leucine (g)
# 771                                      Threonine (g)
# 1992           Vitamin E (Total Alpha-Tocopherol) (mg)
# 1075                                      Tyrosine (g)
# 1160                                     Threonine (g)
# 1023                                       Leucine (g)
# 2622      Total Polyunsaturated Fatty Acids (PUFA) (g)
# 2575      Total Polyunsaturated Fatty Acids (PUFA) (g)
# 976                                        Leucine (g)
# 628       Total Polyunsaturated Fatty Acids (PUFA) (g)
# 813                                     Isoleucine (g)
# 1161                                    Isoleucine (g)
# 1128                                 Total Protein (g)
# 812                                      Threonine (g)
#
#                                                  var2  abs_correlation
# 2095                        Acesulfame Potassium (mg)         1.000000
# 2441               Added Sugars (by Total Sugars) (g)         1.000000
# 423                                       Sodium (mg)         1.000000
# 2283                  Glycemic Load (bread reference)         1.000000
# 2154                 Glycemic Index (bread reference)         0.999999
# 2660                          Omega-6 Fatty Acids (g)         0.999993
# 20                          Kcals from Saturated Fats         0.999961
# 2075                                   Genistein (mg)         0.999960
# 2360                                     Nitrogen (g)         0.999882
# 2517   PUFA 18:3 n-3 (alpha-linolenic acid [ALA]) (g)         0.999870
# 586                        MUFA 18:1 (oleic acid) (g)         0.999818
# 2518   PUFA 18:3 n-3 (alpha-linolenic acid [ALA]) (g)         0.999784
# 2590           PUFA 18:2 n-6 (linoleic acid [LA]) (g)         0.999740
# 2637                          Omega-6 Fatty Acids (g)         0.999721
# 1935                          Omega-3 Fatty Acids (g)         0.999676
# 2100                       Available Carbohydrate (g)         0.999546
# 1070                                       Valine (g)         0.999326
# 771                                    Isoleucine (g)         0.999172
# 1992             Vitamin E (International Units) (IU)         0.999056
# 1075                                       Valine (g)         0.998864
# 1160                                    Histidine (g)         0.998638
# 1023                                     Tyrosine (g)         0.998613
# 2622                          Omega-6 Fatty Acids (g)         0.998606
# 2575           PUFA 18:2 n-6 (linoleic acid [LA]) (g)         0.998602
# 976                                 Phenylalanine (g)         0.998444
# 628   PUFA 18:2 (linoleic acid, undifferentiated) (g)         0.998370
# 813                                       Leucine (g)         0.998342
# 1161                                    Histidine (g)         0.998287
# 1128                                    Histidine (g)         0.998258
# 812                                       Leucine (g)         0.998177

# %%
to_drop = set()

for var1, var2, corr_val in high_corr_pairs:
    if var2 not in to_drop and var1 not in to_drop:
        to_drop.add(var2)

reduced_nutrition_vars = [col for col in nutrition_vars if col not in to_drop]

# %%
print("Original nutrition variables:", len(nutrition_vars))
print("Dropped due to high correlation:", len(to_drop))
print("Remaining nutrition variables:", len(reduced_nutrition_vars))

print("\nDropped variables:")
print(sorted(to_drop))
# Out:
# Original nutrition variables: 186
# Dropped due to high correlation: 133
# Remaining nutrition variables: 53
#
# Dropped variables:
# ['% Calories from Added Sugars (by Total Sugars)', '% Calories from Carbohydrate', '% Calories from MUFA', '% Calories from SFA.x', 'Acesulfame Potassium (mg)', 'Added Sugars (by Available Carbohydrate) (g)', 'Added Sugars (by Total Sugars) (g)', 'Alanine (g)', 'Alpha-Carotene (provitamin A carotenoid) (mcg)', 'Arginine (g)', 'Ash (g)', 'Aspartic Acid (g)', 'Available Carbohydrate (g)', 'Beta-Carotene (provitamin A carotenoid) (mcg)', 'Beta-Carotene Equivalents (derived from provitamin A carotenoids) (mcg)', 'Betaine (mg)', 'Caffeine (mg)', 'Calcium (mg)', 'Cholesterol (mg)', 'Cholesterol to Saturated Fatty Acid Index', 'Choline (mg)', 'Copper (mg)', 'Cystine (g)', 'Dairy Servings in cup equivalents per 1000 kcal', 'Dietary Folate Equivalents (mcg)', 'Energy (kcal).x', 'Fatty Acids Ratio', 'Fructose (g)', 'Gamma-Tocopherol (mg)', 'Genistein (mg)', 'Glucose (g)', 'Glutamic Acid (g)', 'Gluten (g)', 'Glycemic Index (bread reference)', 'Glycemic Load (bread reference)', 'Glycemic Load (glucose reference)', 'Glycine (g)', 'Glycitein (mg)', 'Greens and Beans Servings in cup equivalents', 'HEI 2015 Whole Fruits (0-5)', 'Histidine (g)', 'Insoluble Dietary Fiber (g)', 'Iron (mg)', 'Isoleucine (g)', 'Kcals from Saturated Fats', 'Lactose (g)', 'Lariciresinol (mcg)', 'Leucine (g)', 'Lutein + Zeaxanthin (mcg)', 'Lysine (g)', 'MUFA 16:1 (palmitoleic acid) (g)', 'MUFA 18:1 (oleic acid) (g)', 'MUFA 20:1 (gadoleic acid) (g)', 'Magnesium (mg)', 'Manganese (mg)', 'Methionine (g)', 'Natural Alpha-Tocopherol (RRR-alpha-tocopherol or d-alpha-tocopherol) (mg)', 'Natural Folate (food folate) (mcg)', 'Niacin (vitamin B3) (mg)', 'Niacin Equivalents (mg)', 'Nitrogen (g)', 'Omega-3 Fatty Acids (g)', 'Omega-6 Fatty Acids (g)', 'Oxalic Acid (mg)', 'PUFA 18:2 (linoleic acid, undifferentiated) (g)', 'PUFA 18:2 n-6 (linoleic acid [LA]) (g)', 'PUFA 18:3 (linolenic acid, undifferentiated) (g)', 'PUFA 18:3 n-3 (alpha-linolenic acid [ALA]) (g)', 'Pantothenic Acid (mg)', 'Pectins (g)', 'Phenylalanine (g)', 'Phosphorus (mg)', 'Phytic Acid (mg)', 'Pinoresinol (mcg)', 'Polyunsaturated to Saturated Fat Ratio', 'Potassium (mg)', 'Proline (g)', 'Refined Grains in ounce equivalents', 'Refined Grains in ounce equivalents per 1000 kcal', 'Retinol (mcg)', 'Riboflavin (vitamin B2) (mg)', 'SFA 10:0 (capric acid) (g)', 'SFA 12:0 (lauric acid) (g)', 'SFA 14:0 (myristic acid) (g)', 'SFA 16:0 (palmitic acid) (g)', 'SFA 18:0 (stearic acid) (g)', 'SFA 22:0 (behenic acid) (g)', 'SFA 6:0 (caproic acid) (g)', 'Seafood and Plant Protein Servings in ounce equivalents', 'Selenium (mcg)', 'Serine (g)', 'Sodium (g)', 'Sodium (g) per 1000 kcal', 'Sodium (mg)', 'Solid Fats (g)', 'Soluble Dietary Fiber (g)', 'Starch (g)', 'Sucrose (g)', 'Synthetic Folate (folic acid) (mcg)', 'TRANS 18:2 (trans-octadecadienoic acid) (g)', 'Thiamin (vitamin B1) (mg)', 'Threonine (g)', 'Total Alpha-Tocopherol Equivalents (mg)', 'Total Carbohydrate (g)', 'Total Fat (g)', 'Total Folate (mcg)', 'Total Fruit Servings in cup equivalents per 1000 kcal', 'Total Grains (ounce equivalents)', 'Total Grams', 'Total Monounsaturated Fatty Acids (MUFA) (g)', 'Total Polyunsaturated Fatty Acids (PUFA) (g)', 'Total Protein (g)', 'Total Saturated Fatty Acids (SFA) (g).x', 'Total Sugars (g)', 'Total Trans-Fatty Acids (TRANS) (g)', 'Total Vegetable Servings in cup equivalents per 1000 kcal', 'Total Vitamin A Activity (Retinol Activity Equivalents) (mcg)', 'Total Vitamin A Activity (Retinol Equivalents) (mcg)', 'Tryptophan (g)', 'Tyrosine (g)', 'Valine (g)', 'Vegetable Protein (g)', 'Vitamin B-12 (cobalamin) (mcg)', 'Vitamin B-6 (pyridoxine, pyridoxyl, & pyridoxamine) (mg)', 'Vitamin C (ascorbic acid) (mg)', 'Vitamin D (calciferol) (mcg)', 'Vitamin D2 (ergocalciferol) (mcg)', 'Vitamin D3 (cholecalciferol) (mcg)', 'Vitamin E (International Units) (IU)', 'Vitamin E (Total Alpha-Tocopherol) (mg)', 'Water (g)', 'Whole Grain Servings in ounce equivalents per 1000 kcal', 'Zinc (mg)']

# %%
X_vif = df_variance_clean[reduced_nutrition_vars].copy()

vif_df = pd.DataFrame({
    'Predictor': X_vif.columns,
    'VIF': [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]
})

# %%
vif_df = vif_df.sort_values('VIF', ascending=False)
vif_df
# Out:
#                                             Predictor            VIF
# 23  Total Polyunsaturated Fatty Acids (PUFA) (g) a...  173612.174169
# 0                                HEI 2015 Total Score  141580.314984
# 11                       HEI 2015 Added Sugars (0-10)  103723.377691
# 25                                 Animal Protein (g)   80330.122864
# 36                                % Calories from Fat   53023.574766
# 45                 Glycemic Index (glucose reference)   42363.127858
# 22        Total Protein Servings in ounce equivalents   41516.810187
# 37                            % Calories from Protein   37057.290576
# 24          Kcals from Added Sugars (by Total Sugars)   32705.170434
# 15  Total Protein Servings in ounce equivalents pe...   19773.690132
# 18            Whole Fruit Servings in cup equivalents   16212.152080
# 21                  Dairy Servings in cup equivalents   15905.395615
# 19        Total Vegetable Servings in cup equivalents   14678.112609
# 32                    Vitamin K (phylloquinone) (mcg)   13708.252655
# 6                  HEI 2015 Total Protein Foods (0-5)   11479.170888
# 2                     HEI 2015 Total Vegetables (0-5)   10328.611997
# 38                               % Calories from PUFA    9917.542191
# 28                            Total Dietary Fiber (g)    9674.938356
# 31                              Delta-Tocopherol (mg)    8715.780737
# 35                             3-Methylhistidine (mg)    8416.783853
# 33                         SFA 4:0 (butyric acid) (g)    8358.633186
# 46                                       Inositol (g)    8071.439592
# 5                               HEI 2015 Dairy (0-10)    6446.718375
# 4                        HEI 2015 Whole Grains (0-10)    5907.461538
# 13  Whole Fruit Servings in cup equivalents per 10...    5048.064802
# 12                     HEI 2015 Saturated Fats (0-10)    4750.990701
# 17            Total Fruit Servings in cup equivalents    4708.891631
# 1                         HEI 2015 Total Fruits (0-5)    4672.340907
# 49                                      Tagatose (mg)    3982.738240
# 20          Whole Grain Servings in ounce equivalents    3960.765867
# 8                         HEI 2015 Fatty Acids (0-10)    3430.589255
# 50                                Total Lignans (mcg)    2506.773103
# 52                                 Matairesinol (mcg)    2359.408986
# 48                                       Sorbitol (g)    2306.621378
# 39           TRANS 18:1 (trans-octadecenoic acid) (g)    2075.238288
# 16  Seafood and Plant Protein Servings in ounce eq...    1643.026784
# 10                             HEI 2015 Sodium (0-10)    1564.735801
# 14  Greens and Beans Servings in cup equivalents p...    1430.509648
# 30                               Beta-Tocopherol (mg)    1372.561421
# 27                                        Maltose (g)    1334.999971
# 9                      HEI 2015 Refined Grains (0-10)     825.271165
# 43                                      Daidzein (mg)     735.985179
# 3                     HEI 2015 Greens and Beans (0-5)     706.599486
# 47                                       Mannitol (g)     679.779812
# 7           HEI 2015 Seafood and Plant Proteins (0-5)     502.902913
# 51                         Secoisolariciresinol (mcg)     494.224651
# 29  Total Vitamin A Activity (International Units)...     448.957319
# 41                                     Lycopene (mcg)     395.858358
# 44                                   Biochanin A (mg)     363.706575
# 26                                      Galactose (g)     234.456856
# 40  Beta-Cryptoxanthin (provitamin A carotenoid) (...      82.212088
# 42  Synthetic Alpha-Tocopherol (all rac-alpha-toco...      54.330724
# 34                                     Aspartame (mg)      47.212836

# %%
def compute_vif(df, predictors):
    X = df[predictors].copy()
    vif_df = pd.DataFrame({
        'Predictor': X.columns,
        'VIF': [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    })
    return vif_df.sort_values('VIF', ascending=False)

# %%
vif_reduced_nutrition = compute_vif(df_variance_clean, reduced_nutrition_vars)
vif_reduced_nutrition.head(20)
# Out:
#                                             Predictor            VIF
# 23  Total Polyunsaturated Fatty Acids (PUFA) (g) a...  173612.174169
# 0                                HEI 2015 Total Score  141580.314984
# 11                       HEI 2015 Added Sugars (0-10)  103723.377691
# 25                                 Animal Protein (g)   80330.122864
# 36                                % Calories from Fat   53023.574766
# 45                 Glycemic Index (glucose reference)   42363.127858
# 22        Total Protein Servings in ounce equivalents   41516.810187
# 37                            % Calories from Protein   37057.290576
# 24          Kcals from Added Sugars (by Total Sugars)   32705.170434
# 15  Total Protein Servings in ounce equivalents pe...   19773.690132
# 18            Whole Fruit Servings in cup equivalents   16212.152080
# 21                  Dairy Servings in cup equivalents   15905.395615
# 19        Total Vegetable Servings in cup equivalents   14678.112609
# 32                    Vitamin K (phylloquinone) (mcg)   13708.252655
# 6                  HEI 2015 Total Protein Foods (0-5)   11479.170888
# 2                     HEI 2015 Total Vegetables (0-5)   10328.611997
# 38                               % Calories from PUFA    9917.542191
# 28                            Total Dietary Fiber (g)    9674.938356
# 31                              Delta-Tocopherol (mg)    8715.780737
# 35                             3-Methylhistidine (mg)    8416.783853

# %%
def reduce_vif(df, predictors, vif_threshold=10):
    remaining_vars = predictors.copy()
    removed_vars = []
    
    while True:
        vif_df = compute_vif(df, remaining_vars)
        max_vif = vif_df['VIF'].max()
        
        if max_vif <= vif_threshold:
            break
        
        worst_var = vif_df.iloc[0]['Predictor']
        worst_vif = vif_df.iloc[0]['VIF']
        
        remaining_vars.remove(worst_var)
        removed_vars.append((worst_var, worst_vif))
        
        print(f"Removed {worst_var} with VIF = {worst_vif:.2f}")
    
    final_vif = compute_vif(df, remaining_vars)
    return remaining_vars, removed_vars, final_vif

# %%
vif_clean_nutrition_vars, removed_vif_vars, final_vif_table = reduce_vif(
    df_variance_clean,
    reduced_nutrition_vars,
    vif_threshold=10
)
# Out:
# Removed Total Polyunsaturated Fatty Acids (PUFA) (g) and Total Monounsaturated Fatty Acids (MUFA) (g) with VIF = 173612.17
# Removed HEI 2015 Total Score with VIF = 141578.80
# Removed Animal Protein (g) with VIF = 33934.99
# Removed % Calories from Protein with VIF = 10208.36
# Removed % Calories from Fat with VIF = 8852.40
# Removed Total Dietary Fiber (g) with VIF = 3162.02
# Removed Glycemic Index (glucose reference) with VIF = 2572.67
# Removed Vitamin K (phylloquinone) (mcg) with VIF = 1696.71
# Removed Total Protein Servings in ounce equivalents with VIF = 1644.57
# Removed HEI 2015 Added Sugars (0-10) with VIF = 1167.98
# Removed HEI 2015 Total Protein Foods (0-5) with VIF = 886.87
# Removed HEI 2015 Total Fruits (0-5) with VIF = 466.33
# Removed HEI 2015 Saturated Fats (0-10) with VIF = 408.06
# Removed % Calories from PUFA with VIF = 394.99
# Removed HEI 2015 Total Vegetables (0-5) with VIF = 301.64
# Removed Delta-Tocopherol (mg) with VIF = 261.11
# Removed Whole Fruit Servings in cup equivalents with VIF = 200.44
# Removed Total Fruit Servings in cup equivalents with VIF = 158.04
# Removed Total Vegetable Servings in cup equivalents with VIF = 146.62
# Removed Total Lignans (mcg) with VIF = 122.03
# Removed SFA 4:0 (butyric acid) (g) with VIF = 104.85
# Removed HEI 2015 Dairy (0-10) with VIF = 90.44
# Removed Total Protein Servings in ounce equivalents per 1000 kcal with VIF = 74.92
# Removed HEI 2015 Seafood and Plant Proteins (0-5) with VIF = 62.21
# Removed Whole Grain Servings in ounce equivalents with VIF = 46.82
# Removed Maltose (g) with VIF = 41.09
# Removed Dairy Servings in cup equivalents with VIF = 38.87
# Removed Greens and Beans Servings in cup equivalents per 1000 kcal with VIF = 34.82
# Removed Inositol (g) with VIF = 31.95
# Removed HEI 2015 Sodium (0-10) with VIF = 22.13
# Removed Total Vitamin A Activity (International Units) (IU) with VIF = 20.28
# Removed HEI 2015 Fatty Acids (0-10) with VIF = 18.23
# Removed Beta-Cryptoxanthin (provitamin A carotenoid) (mcg) with VIF = 15.23
# Removed HEI 2015 Refined Grains (0-10) with VIF = 13.72
# Removed Matairesinol (mcg) with VIF = 13.19
# Removed Lycopene (mcg) with VIF = 12.12
# Removed Kcals from Added Sugars (by Total Sugars) with VIF = 11.07

# %%
print("\nOriginal reduced_nutrition_vars:", len(reduced_nutrition_vars))
print("Removed by VIF filtering:", len(removed_vif_vars))
print("Final VIF-cleaned nutrition vars:", len(vif_clean_nutrition_vars))
# Out:
# Original reduced_nutrition_vars: 53
# Removed by VIF filtering: 37
# Final VIF-cleaned nutrition vars: 16

# %%
removed_vif_df = pd.DataFrame(removed_vif_vars, columns=['Removed_Variable', 'VIF_at_Removal'])

# %%
final_vif_table
# Out:
#                                             Predictor       VIF
# 8            TRANS 18:1 (trans-octadecenoic acid) (g)  7.782450
# 7                              3-Methylhistidine (mg)  7.756311
# 12                                       Mannitol (g)  7.685965
# 13                                       Sorbitol (g)  7.418933
# 0                     HEI 2015 Greens and Beans (0-5)  6.845989
# 5                                Beta-Tocopherol (mg)  6.766840
# 3   Seafood and Plant Protein Servings in ounce eq...  6.029183
# 2   Whole Fruit Servings in cup equivalents per 10...  5.224193
# 1                        HEI 2015 Whole Grains (0-10)  4.459261
# 4                                       Galactose (g)  2.905277
# 11                                   Biochanin A (mg)  2.645320
# 10                                      Daidzein (mg)  1.935345
# 15                         Secoisolariciresinol (mcg)  1.833695
# 14                                      Tagatose (mg)  1.457726
# 9   Synthetic Alpha-Tocopherol (all rac-alpha-toco...  1.183754
# 6                                      Aspartame (mg)  1.155018

# %%
print(vif_clean_nutrition_vars)
# Out:
# ['HEI 2015 Greens and Beans (0-5)', 'HEI 2015 Whole Grains (0-10)', 'Whole Fruit Servings in cup equivalents per 1000 kcal', 'Seafood and Plant Protein Servings in ounce equivalents per 1000 kcal', 'Galactose (g)', 'Beta-Tocopherol (mg)', 'Aspartame (mg)', '3-Methylhistidine (mg)', 'TRANS 18:1 (trans-octadecenoic acid) (g)', 'Synthetic Alpha-Tocopherol (all rac-alpha-tocopherol or dl-alpha-tocopherol) (mg)', 'Daidzein (mg)', 'Biochanin A (mg)', 'Mannitol (g)', 'Sorbitol (g)', 'Tagatose (mg)', 'Secoisolariciresinol (mcg)']

# %% [markdown]
# ### Fitting the model

# %%
ses_vars = [
    'student_low_income_percent',
    'student_disabilities_percent'
]

target_outcome = 'Math_Proficiency'  

final_predictors = ses_vars + vif_clean_nutrition_vars

X = df_variance_clean[final_predictors].copy()
y = df_variance_clean[target_outcome].copy()

X = sm.add_constant(X)
vif_clean_model = sm.OLS(y, X).fit()

print(vif_clean_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Math_Proficiency   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.747
# Method:                 Least Squares   F-statistic:                     9.689
# Date:                Sun, 26 Apr 2026   Prob (F-statistic):           8.36e-09
# Time:                        02:13:14   Log-Likelihood:                -189.87
# No. Observations:                  54   AIC:                             417.7
# Df Residuals:                      35   BIC:                             455.5
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================================================================
#                                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                96.9963     13.024      7.447      0.000      70.556     123.437
# student_low_income_percent                                                           -0.4364      0.061     -7.103      0.000      -0.561      -0.312
# student_disabilities_percent                                                         -0.4323      0.438     -0.986      0.331      -1.322       0.457
# HEI 2015 Greens and Beans (0-5)                                                      -4.3988      2.031     -2.166      0.037      -8.522      -0.276
# HEI 2015 Whole Grains (0-10)                                                         -3.0776      0.885     -3.476      0.001      -4.875      -1.280
# Whole Fruit Servings in cup equivalents per 1000 kcal                                -9.4773      7.925     -1.196      0.240     -25.565       6.611
# Seafood and Plant Protein Servings in ounce equivalents per 1000 kcal                 5.0152      4.749      1.056      0.298      -4.625      14.656
# Galactose (g)                                                                        -2.3662      3.866     -0.612      0.544     -10.214       5.481
# Beta-Tocopherol (mg)                                                                 10.7863      8.183      1.318      0.196      -5.827      27.400
# Aspartame (mg)                                                                       -4.0637      4.438     -0.916      0.366     -13.073       4.945
# 3-Methylhistidine (mg)                                                               -1.8307      0.588     -3.114      0.004      -3.024      -0.637
# TRANS 18:1 (trans-octadecenoic acid) (g)                                              4.4918      2.807      1.600      0.119      -1.207      10.190
# Synthetic Alpha-Tocopherol (all rac-alpha-tocopherol or dl-alpha-tocopherol) (mg)     1.6233      2.694      0.603      0.551      -3.846       7.093
# Daidzein (mg)                                                                         0.3550      0.358      0.993      0.328      -0.371       1.081
# Biochanin A (mg)                                                                      0.0767      8.317      0.009      0.993     -16.807      16.961
# Mannitol (g)                                                                         17.5013     10.669      1.640      0.110      -4.158      39.160
# Sorbitol (g)                                                                        -10.5734      3.751     -2.819      0.008     -18.188      -2.959
# Tagatose (mg)                                                                         0.0234      0.219      0.107      0.916      -0.422       0.469
# Secoisolariciresinol (mcg)                                                            0.0018      0.011      0.162      0.872      -0.020       0.024
# ==============================================================================
# Omnibus:                        1.577   Durbin-Watson:                   2.460
# Prob(Omnibus):                  0.455   Jarque-Bera (JB):                1.484
# Skew:                          -0.387   Prob(JB):                        0.476
# Kurtosis:                       2.752   Cond. No.                     1.92e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.92e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fitted_vals = vif_clean_model.fittedvalues
residuals = vif_clean_model.resid

plt.figure(figsize=(7,5))
sns.scatterplot(x=fitted_vals, y=residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Residuals vs Fitted")
plt.tight_layout()
plt.show()

# %%
sm.qqplot(vif_clean_model.resid, line='45', fit=True)
plt.title("QQ Plot of Residuals")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(vif_clean_model.resid, kde=True)
plt.xlabel("Residuals")
plt.title("Histogram of Residuals")
plt.tight_layout()
plt.show()

# %%
influence = vif_clean_model.get_influence()
std_resid = influence.resid_studentized_internal
sqrt_abs_std_resid = np.sqrt(np.abs(std_resid))

plt.figure(figsize=(7,5))
sns.scatterplot(x=fitted_vals, y=sqrt_abs_std_resid)
plt.xlabel("Fitted values")
plt.ylabel("Sqrt(|Standardized residuals|)")
plt.title("Scale-Location Plot")
plt.tight_layout()
plt.show()
# Out:
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:847: RuntimeWarning: invalid value encountered in sqrt
#   return self.resid / sigma / np.sqrt(1 - hii)

# %%
bp_test = het_breuschpagan(vif_clean_model.resid, vif_clean_model.model.exog)

bp_results = pd.DataFrame({
    'Statistic': ['LM Statistic', 'LM p-value', 'F Statistic', 'F p-value'],
    'Value': bp_test
})

bp_results
# Out:
#       Statistic      Value
# 0  LM Statistic  11.919376
# 1    LM p-value   0.851372
# 2   F Statistic   0.550766
# 3     F p-value   0.910379

# %%
dw_stat = durbin_watson(vif_clean_model.resid)
print("Durbin-Watson statistic:", round(dw_stat, 4))
# Out:
# Durbin-Watson statistic: 2.4596

# %%
residual_df = pd.DataFrame({
    'index': df_variance_clean.index,
    'fitted': vif_clean_model.fittedvalues,
    'residual': vif_clean_model.resid
})

residual_df.head()
# Out:
#    index     fitted   residual
# 0      0  28.498853 -10.468084
# 1      1  52.539193   8.060807
# 2      2  51.698501  -6.098501
# 3      3  46.480931  -0.980931
# 4      4  15.554791  -5.854791

# %%
# Get influence measures from the fitted model
influence = OLSInfluence(vif_clean_model)

diagnostics_df = pd.DataFrame({
    'index': df_variance_clean.index,
    'studentized_residual': influence.resid_studentized_external,
    'cooks_distance': influence.cooks_distance[0]
})
# Out:
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:847: RuntimeWarning: invalid value encountered in sqrt
#   return self.resid / sigma / np.sqrt(1 - hii)

# %%
n = len(df_variance_clean)
studentized_cutoff = 2
cooks_cutoff = 4 / n

# %%
# Flag points
diagnostics_df['outlier_by_studentized'] = diagnostics_df['studentized_residual'].abs() > studentized_cutoff
diagnostics_df['influential_by_cooks'] = diagnostics_df['cooks_distance'] > cooks_cutoff

# %%
# Final points flagged by either method
final_flagged_points = diagnostics_df[
    (diagnostics_df['outlier_by_studentized']) | (diagnostics_df['influential_by_cooks'])
].copy()

# %%
# Sort so the most suspicious points come first
final_flagged_points = final_flagged_points.sort_values(
    by=['outlier_by_studentized', 'cooks_distance'],
    ascending=False
)

# %%
print("Studentized residual cutoff:", studentized_cutoff)
print("Cook's distance cutoff:", round(cooks_cutoff, 4))

print("\nFinal flagged points:")
print(final_flagged_points)
# Out:
# Studentized residual cutoff: 2
# Cook's distance cutoff: 0.0741
#
# Final flagged points:
#     index  studentized_residual  cooks_distance  outlier_by_studentized  \
# 48     48             -2.775647        0.100174                    True
# 38     38              0.817287        8.611696                   False
# 15     15              1.995139        0.993571                   False
# 32     32             -0.371157        0.347280                   False
# 53     53              1.407491        0.313189                   False
# 17     17              0.450681        0.294653                   False
# 28     28              1.846442        0.162248                   False
# 37     37             -1.663275        0.081167                   False
#
#     influential_by_cooks
# 48                  True
# 38                  True
# 15                  True
# 32                  True
# 53                  True
# 17                  True
# 28                  True
# 37                  True

# %%
print(final_flagged_points['index'].tolist())
# Out:
# [48, 38, 15, 32, 53, 17, 28, 37]

# %% [markdown]
# ### Fitting after removing influential points

# %%
flagged_points = [48, 38, 15, 32, 53, 17, 28, 37]

df_no_influential = df_variance_clean.drop(index=flagged_points).copy()

# %%
print("Original shape:", df_variance_clean.shape)
print("New shape after removing flagged points:", df_no_influential.shape)
# Out:
# Original shape: (54, 191)
# New shape after removing flagged points: (46, 191)

# %%
X_new = df_no_influential[final_predictors].copy()
y_new = df_no_influential['Math_Proficiency'].copy()

X_new = sm.add_constant(X_new)
model_no_influential = sm.OLS(y_new, X_new).fit()

print(model_no_influential.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Math_Proficiency   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.800
# Method:                 Least Squares   F-statistic:                     11.01
# Date:                Sun, 26 Apr 2026   Prob (F-statistic):           3.66e-08
# Time:                        02:13:15   Log-Likelihood:                -155.60
# No. Observations:                  46   AIC:                             349.2
# Df Residuals:                      27   BIC:                             383.9
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================================================================
#                                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                               104.1855     15.322      6.800      0.000      72.748     135.623
# student_low_income_percent                                                           -0.4373      0.062     -7.101      0.000      -0.564      -0.311
# student_disabilities_percent                                                         -0.8931      0.493     -1.812      0.081      -1.905       0.118
# HEI 2015 Greens and Beans (0-5)                                                      -3.6991      2.021     -1.831      0.078      -7.845       0.447
# HEI 2015 Whole Grains (0-10)                                                         -2.8498      0.901     -3.162      0.004      -4.699      -1.000
# Whole Fruit Servings in cup equivalents per 1000 kcal                                -8.5929      7.681     -1.119      0.273     -24.353       7.167
# Seafood and Plant Protein Servings in ounce equivalents per 1000 kcal                 3.1465      5.050      0.623      0.538      -7.216      13.509
# Galactose (g)                                                                        -6.2651      7.973     -0.786      0.439     -22.625      10.095
# Beta-Tocopherol (mg)                                                                 16.8228      8.658      1.943      0.062      -0.941      34.587
# Aspartame (mg)                                                                       -4.4630      4.215     -1.059      0.299     -13.111       4.185
# 3-Methylhistidine (mg)                                                               -1.7396      0.575     -3.023      0.005      -2.920      -0.559
# TRANS 18:1 (trans-octadecenoic acid) (g)                                              5.1018      5.310      0.961      0.345      -5.794      15.997
# Synthetic Alpha-Tocopherol (all rac-alpha-tocopherol or dl-alpha-tocopherol) (mg)     4.9716     15.219      0.327      0.746     -26.256      36.199
# Daidzein (mg)                                                                        -3.8545      4.567     -0.844      0.406     -13.226       5.517
# Biochanin A (mg)                                                                      0.1284      8.419      0.015      0.988     -17.146      17.402
# Mannitol (g)                                                                         14.6322     11.246      1.301      0.204      -8.443      37.707
# Sorbitol (g)                                                                         -9.8248      3.819     -2.573      0.016     -17.660      -1.989
# Tagatose (mg)                                                                        -0.0605      0.823     -0.074      0.942      -1.749       1.628
# Secoisolariciresinol (mcg)                                                           -0.0099      0.051     -0.195      0.847      -0.115       0.095
# ==============================================================================
# Omnibus:                        1.312   Durbin-Watson:                   2.502
# Prob(Omnibus):                  0.519   Jarque-Bera (JB):                1.050
# Skew:                          -0.117   Prob(JB):                        0.592
# Kurtosis:                       2.298   Cond. No.                         927.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x=model_no_influential.fittedvalues, y=model_no_influential.resid)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Math Model After Removing Influential Points: Residuals vs Fitted")
plt.tight_layout()
plt.show()

# %%
sm.qqplot(model_no_influential.resid, line='45', fit=True)
plt.title("Math Model After Removing Influential Points: QQ Plot")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(model_no_influential.resid, kde=True)
plt.xlabel("Residuals")
plt.title("Histogram of Residuals")
plt.tight_layout()
plt.show()

# %%
bp_test_new = het_breuschpagan(model_no_influential.resid, model_no_influential.model.exog)

bp_results_new = pd.DataFrame({
    'Statistic': ['LM Statistic', 'LM p-value', 'F Statistic', 'F p-value'],
    'Value': bp_test_new
})

bp_results_new
# Out:
#       Statistic      Value
# 0  LM Statistic  13.194747
# 1    LM p-value   0.779876
# 2   F Statistic   0.603322
# 3     F p-value   0.865980

# %%
influence_new = OLSInfluence(model_no_influential)

diag_new = pd.DataFrame({
    'index': df_no_influential.index,
    'studentized_residual': influence_new.resid_studentized_external,
    'cooks_distance': influence_new.cooks_distance[0]
})

studentized_cutoff = 2
cooks_cutoff = 4 / len(df_no_influential)

diag_new['flag_outlier'] = diag_new['studentized_residual'].abs() > studentized_cutoff
diag_new['flag_influential'] = diag_new['cooks_distance'] > cooks_cutoff

final_flagged_new = diag_new[
    (diag_new['flag_outlier']) | (diag_new['flag_influential'])
].copy()
# Out:
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:847: RuntimeWarning: invalid value encountered in sqrt
#   return self.resid / sigma / np.sqrt(1 - hii)

# %%
print("Studentized residual cutoff:", studentized_cutoff)
print("Cook's distance cutoff:", round(cooks_cutoff, 4))

print("\nRemaining flagged points after refitting:")
print(final_flagged_new)
# Out:
# Studentized residual cutoff: 2
# Cook's distance cutoff: 0.087
#
# Remaining flagged points after refitting:
#     index  studentized_residual  cooks_distance  flag_outlier  \
# 12     12              2.032494        4.496110          True
# 18     18              1.717283        1.925603         False
# 31     31              1.741287        0.099785         False
# 35     35             -1.704115        0.106877         False
#
#     flag_influential
# 12              True
# 18              True
# 31              True
# 35              True

# %%
print(final_flagged_new['index'].tolist())
# Out:
# [12, 18, 31, 35]

# %%
# influence measures from the refit model
influence = OLSInfluence(model_no_influential)
cooks_d = influence.cooks_distance[0]

# cutoff
n = len(df_no_influential)
cooks_cutoff = 4 / n

# Cook's distance plot
plt.figure(figsize=(10, 4))
plt.stem(df_no_influential.index, cooks_d, basefmt=" ")
plt.axhline(cooks_cutoff, color='red', linestyle='--', label=f"Cutoff = {cooks_cutoff:.4f}")
plt.xlabel("Observation index")
plt.ylabel("Cook's Distance")
plt.title("Cook's Distance Plot")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:847: RuntimeWarning: invalid value encountered in sqrt
#   return self.resid / sigma / np.sqrt(1 - hii)

# %% [markdown]
# ### MODEL 2: RIDGE MODEL FOR Math

# %%
vif_clean_nutrition_vars
# Out:
# ['HEI 2015 Greens and Beans (0-5)',
#  'HEI 2015 Whole Grains (0-10)',
#  'Whole Fruit Servings in cup equivalents per 1000 kcal',
#  'Seafood and Plant Protein Servings in ounce equivalents per 1000 kcal',
#  'Galactose (g)',
#  'Beta-Tocopherol (mg)',
#  'Aspartame (mg)',
#  '3-Methylhistidine (mg)',
#  'TRANS 18:1 (trans-octadecenoic acid) (g)',
#  'Synthetic Alpha-Tocopherol (all rac-alpha-tocopherol or dl-alpha-tocopherol) (mg)',
#  'Daidzein (mg)',
#  'Biochanin A (mg)',
#  'Mannitol (g)',
#  'Sorbitol (g)',
#  'Tagatose (mg)',
#  'Secoisolariciresinol (mcg)']

# %%
# choose outcome
target_outcome = 'Math_Proficiency'   

# predictors: SES + filtered nutrition variables
ses_vars = ['student_low_income_percent', 'student_disabilities_percent']
ridge_predictors = ses_vars + vif_clean_nutrition_vars

# %%
# build X and y
X = df_variance_clean[ridge_predictors].copy()
y = df_variance_clean[target_outcome].copy()

# %%
# scale X
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# choose lambda (alpha) by cross-validation
alphas = np.logspace(-3, 3, 100)
ridge_cv = RidgeCV(alphas=alphas, cv=5)
ridge_cv.fit(X_scaled, y)

best_alpha = ridge_cv.alpha_
print("Best lambda (alpha):", best_alpha)
# Out:
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# ...
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Best lambda (alpha): 11.497569953977356
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
# fit final ridge model
ridge_model = Ridge(alpha=best_alpha)
ridge_model.fit(X_scaled, y)

# coefficient table
ridge_coef_table = pd.DataFrame({
    'Predictor': ridge_predictors,
    'Ridge_Coefficient': ridge_model.coef_
}).sort_values('Ridge_Coefficient', key=np.abs, ascending=False)

print("\nTop coefficients:")
print(ridge_coef_table.head(20))
# Out:
# Top coefficients:
#                                             Predictor  Ridge_Coefficient
# 0                          student_low_income_percent         -10.410539
# 9                              3-Methylhistidine (mg)          -4.119587
# 3                        HEI 2015 Whole Grains (0-10)          -4.048218
# 15                                       Sorbitol (g)          -3.684522
# 2                     HEI 2015 Greens and Beans (0-5)          -3.289528
# 5   Seafood and Plant Protein Servings in ounce eq...           2.992369
# 8                                      Aspartame (mg)          -1.810316
# 1                        student_disabilities_percent          -1.807797
# 7                                Beta-Tocopherol (mg)           1.706851
# 10           TRANS 18:1 (trans-octadecenoic acid) (g)           1.334645
# 4   Whole Fruit Servings in cup equivalents per 10...          -0.995767
# 6                                       Galactose (g)          -0.824166
# 12                                      Daidzein (mg)           0.724525
# 14                                       Mannitol (g)           0.472789
# 16                                      Tagatose (mg)           0.448201
# 17                         Secoisolariciresinol (mcg)           0.208453
# 13                                   Biochanin A (mg)           0.189546
# 11  Synthetic Alpha-Tocopherol (all rac-alpha-toco...          -0.071549

# %%
# cross-validated performance
cv_rmse = -cross_val_score(ridge_model, X_scaled, y, cv=5, scoring='neg_root_mean_squared_error')
cv_mae = -cross_val_score(ridge_model, X_scaled, y, cv=5, scoring='neg_mean_absolute_error')
cv_r2 = cross_val_score(ridge_model, X_scaled, y, cv=5, scoring='r2')

print("\nCV RMSE mean:", round(cv_rmse.mean(), 4))
print("CV MAE mean:", round(cv_mae.mean(), 4))
print("CV R^2 mean:", round(cv_r2.mean(), 4))
# Out:
# CV RMSE mean: 12.5823
# CV MAE mean: 10.7169
# CV R^2 mean: 0.5806
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
zero_pct = (X == 0).mean().sort_values(ascending=False)
zero_pct.head(20)
# Out:
# Aspartame (mg)                                                                       0.981481
# Synthetic Alpha-Tocopherol (all rac-alpha-tocopherol or dl-alpha-tocopherol) (mg)    0.925926
# Whole Fruit Servings in cup equivalents per 1000 kcal                                0.055556
# HEI 2015 Greens and Beans (0-5)                                                      0.037037
# Seafood and Plant Protein Servings in ounce equivalents per 1000 kcal                0.037037
# Biochanin A (mg)                                                                     0.018519
# student_low_income_percent                                                           0.000000
# Tagatose (mg)                                                                        0.000000
# Sorbitol (g)                                                                         0.000000
# Mannitol (g)                                                                         0.000000
# Daidzein (mg)                                                                        0.000000
# 3-Methylhistidine (mg)                                                               0.000000
# TRANS 18:1 (trans-octadecenoic acid) (g)                                             0.000000
# student_disabilities_percent                                                         0.000000
# Beta-Tocopherol (mg)                                                                 0.000000
# Galactose (g)                                                                        0.000000
# HEI 2015 Whole Grains (0-10)                                                         0.000000
# Secoisolariciresinol (mcg)                                                           0.000000
# dtype: float64

# %%
target_outcome = 'Math_Proficiency'

ses_vars = ['student_low_income_percent', 'student_disabilities_percent']
ridge_predictors = ses_vars + vif_clean_nutrition_vars

X = df_variance_clean[ridge_predictors].copy()
y = df_variance_clean[target_outcome].copy()

# remove sparse variables (>80% zeros), except SES
zero_pct = (X == 0).mean()
sparse_drop = [col for col in X.columns if col not in ses_vars and zero_pct[col] > 0.80]

# manually remove highly skewed / unstable niche variables
manual_drop = [
    'Daidzein (mg)',
    'Tagatose (mg)',
    'Secoisolariciresinol (mcg)',
    'Biochanin A (mg)'
]

# %%
manual_drop = [col for col in manual_drop if col in X.columns]

drop_cols = list(set(sparse_drop + manual_drop))
X = X.drop(columns=drop_cols)

print("Dropped columns:")
print(drop_cols)

# log-transform nonnegative non-SES predictors
X_clean = X.copy()
for col in X_clean.columns:
    if col not in ses_vars and (X_clean[col] >= 0).all():
        X_clean[col] = np.log1p(X_clean[col])

# scale predictors
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_clean)
# Out:
# Dropped columns:
# ['Secoisolariciresinol (mcg)', 'Synthetic Alpha-Tocopherol (all rac-alpha-tocopherol or dl-alpha-tocopherol) (mg)', 'Biochanin A (mg)', 'Aspartame (mg)', 'Daidzein (mg)', 'Tagatose (mg)']

# %%
# choose best lambda using CV
alphas = np.logspace(-3, 3, 100)
ridge_cv = RidgeCV(alphas=alphas, cv=5)
ridge_cv.fit(X_scaled, y)

best_alpha = ridge_cv.alpha_
print("Best lambda (alpha):", best_alpha)
# Out:
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# ...
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
#  7.56463327554629

# %%
# fit final ridge model
ridge_model_clean = Ridge(alpha=best_alpha)
ridge_model_clean.fit(X_scaled, y)

# coefficient table
ridge_coef_table_clean = pd.DataFrame({
    'Predictor': X_clean.columns,
    'Ridge_Coefficient': ridge_model_clean.coef_
}).sort_values('Ridge_Coefficient', key=np.abs, ascending=False)

print("\nTop coefficients:")
print(ridge_coef_table_clean.head(20))
# Out:
# Top coefficients:
#                                             Predictor  Ridge_Coefficient
# 0                          student_low_income_percent         -11.392099
# 3                        HEI 2015 Whole Grains (0-10)          -4.661015
# 8                              3-Methylhistidine (mg)          -4.528467
# 11                                       Sorbitol (g)          -4.361424
# 2                     HEI 2015 Greens and Beans (0-5)          -3.210440
# 7                                Beta-Tocopherol (mg)           2.398816
# 5   Seafood and Plant Protein Servings in ounce eq...           2.215121
# 9            TRANS 18:1 (trans-octadecenoic acid) (g)           2.111772
# 1                        student_disabilities_percent          -2.095433
# 10                                       Mannitol (g)           1.584782
# 6                                       Galactose (g)          -1.434074
# 4   Whole Fruit Servings in cup equivalents per 10...          -0.944833

# %%
# cross-validated performance
cv_rmse = -cross_val_score(ridge_model_clean, X_scaled, y, cv=5, scoring='neg_root_mean_squared_error')
cv_mae = -cross_val_score(ridge_model_clean, X_scaled, y, cv=5, scoring='neg_mean_absolute_error')
cv_r2 = cross_val_score(ridge_model_clean, X_scaled, y, cv=5, scoring='r2')

print("\nCV RMSE mean:", round(cv_rmse.mean(), 4))
print("CV MAE mean:", round(cv_mae.mean(), 4))
print("CV R^2 mean:", round(cv_r2.mean(), 4))
# Out:
# CV RMSE mean: 11.3728
# CV MAE mean: 9.8159
# CV R^2 mean: 0.6525
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %% [markdown]
# ### MODEL 3: Lasso on all predictors

# %%
df_variance_clean.columns
# Out:
# Index(['student_disabilities_percent', 'student_low_income_percent',
#        'HEI 2015 Total Score', 'HEI 2015 Total Fruits (0-5)',
#        'HEI 2015 Whole Fruits (0-5)', 'HEI 2015 Total Vegetables (0-5)',
#        'HEI 2015 Greens and Beans (0-5)', 'HEI 2015 Whole Grains (0-10)',
#        'HEI 2015 Dairy (0-10)', 'HEI 2015 Total Protein Foods (0-5)',
#        ...
#        'Total Lignans (mcg)', 'Secoisolariciresinol (mcg)',
#        'Matairesinol (mcg)', 'Lariciresinol (mcg)', 'Pinoresinol (mcg)',
#        'PUFA 18:2 n-6 (linoleic acid [LA]) (g)', 'Omega-6 Fatty Acids (g)',
#        'ELA_Proficiency', 'Math_Proficiency', 'Science_Proficiency'],
#       dtype='object', length=191)

# %%
df = df_variance_clean.copy()

target = 'Math_Proficiency'
outcome_cols = ['ELA_Proficiency', 'Math_Proficiency', 'Science_Proficiency']

# %%
predictors = [col for col in df.columns if col not in outcome_cols]

print("Number of predictors:", len(predictors))
# Out:
# Number of predictors: 188

# %%
X = df[predictors].copy()
y = df[target].copy()

print(X.shape)
print(y.shape)
# Out:
# (54, 188)
# (54,)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
lasso_cv = LassoCV(cv=5, random_state=42, max_iter=10000)
lasso_cv.fit(X_scaled, y)

best_alpha = lasso_cv.alpha_
print("Best lambda (alpha):", best_alpha)
# Out:
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.379e+00, tolerance: 1.583e+00
#   model = cd_fast.enet_coordinate_descent(
# Best lambda (alpha): 1.3037526380059032

# %%
lasso_model = Lasso(alpha=best_alpha, max_iter=10000)
lasso_model.fit(X_scaled, y)
# Out:
# Lasso(alpha=np.float64(1.3037526380059032), max_iter=10000)

# %%
lasso_coef_table = pd.DataFrame({
    'Predictor': X.columns,
    'Lasso_Coefficient': lasso_model.coef_
}).sort_values('Lasso_Coefficient', key=np.abs, ascending=False)

lasso_coef_table.head(30)
# Out:
#                                              Predictor  Lasso_Coefficient
# 1                           student_low_income_percent         -12.701336
# 29             Total Fruit Servings in cup equivalents          -3.308358
# 28                               % Calories from SFA.x          -2.913768
# 142  Beta-Cryptoxanthin (provitamin A carotenoid) (...          -2.299263
# 20   Whole Grain Servings in ounce equivalents per ...          -2.240239
# 12                      HEI 2015 Refined Grains (0-10)          -1.382625
# 126                             3-Methylhistidine (mg)          -0.828057
# 98                         SFA 22:0 (behenic acid) (g)           0.754193
# 141     Alpha-Carotene (provitamin A carotenoid) (mcg)          -0.562304
# 0                         student_disabilities_percent          -0.495468
# 143                          Lutein + Zeaxanthin (mcg)          -0.082308
# 178     PUFA 18:3 n-3 (alpha-linolenic acid [ALA]) (g)          -0.000000
# 128                                          Water (g)           0.000000
# 120                                        Proline (g)          -0.000000
# 121                                         Serine (g)          -0.000000
# 122                                     Aspartame (mg)          -0.000000
# 123                                      Caffeine (mg)           0.000000
# 124                                   Phytic Acid (mg)           0.000000
# 125                                   Oxalic Acid (mg)           0.000000
# 185                                  Pinoresinol (mcg)           0.000000
# 127                                            Ash (g)          -0.000000
# 129                                % Calories from Fat          -0.000000
# 118                                  Glutamic Acid (g)          -0.000000
# 130                       % Calories from Carbohydrate           0.000000
# 131                            % Calories from Protein          -0.000000
# 132                               % Calories from MUFA           0.000000
# 133                               % Calories from PUFA          -0.000000
# 134             Polyunsaturated to Saturated Fat Ratio           0.000000
# 135          Cholesterol to Saturated Fatty Acid Index          -0.000000
# 136  Total Vitamin A Activity (Retinol Equivalents)...          -0.000000

# %%
lasso_selected = lasso_coef_table[lasso_coef_table['Lasso_Coefficient'] != 0].copy()
lasso_selected
# Out:
#                                              Predictor  Lasso_Coefficient
# 1                           student_low_income_percent         -12.701336
# 29             Total Fruit Servings in cup equivalents          -3.308358
# 28                               % Calories from SFA.x          -2.913768
# 142  Beta-Cryptoxanthin (provitamin A carotenoid) (...          -2.299263
# 20   Whole Grain Servings in ounce equivalents per ...          -2.240239
# 12                      HEI 2015 Refined Grains (0-10)          -1.382625
# 126                             3-Methylhistidine (mg)          -0.828057
# 98                         SFA 22:0 (behenic acid) (g)           0.754193
# 141     Alpha-Carotene (provitamin A carotenoid) (mcg)          -0.562304
# 0                         student_disabilities_percent          -0.495468
# 143                          Lutein + Zeaxanthin (mcg)          -0.082308

# %%
selected_predictors = lasso_selected['Predictor'].tolist()

print("Selected predictors:")
print(selected_predictors)
print("Number selected:", len(selected_predictors))
# Out:
# Selected predictors:
# ['student_low_income_percent', 'Total Fruit Servings in cup equivalents', '% Calories from SFA.x', 'Beta-Cryptoxanthin (provitamin A carotenoid) (mcg)', 'Whole Grain Servings in ounce equivalents per 1000 kcal', 'HEI 2015 Refined Grains (0-10)', '3-Methylhistidine (mg)', 'SFA 22:0 (behenic acid) (g)', 'Alpha-Carotene (provitamin A carotenoid) (mcg)', 'student_disabilities_percent', 'Lutein + Zeaxanthin (mcg)']
# Number selected: 11

# %%
X_ols = df[selected_predictors].copy()
y_ols = df[target].copy()

X_ols = sm.add_constant(X_ols)
lasso_ols_model = sm.OLS(y_ols, X_ols).fit()

print(lasso_ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Math_Proficiency   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     22.76
# Date:                Sun, 26 Apr 2026   Prob (F-statistic):           3.05e-14
# Time:                        02:13:17   Log-Likelihood:                -185.78
# No. Observations:                  54   AIC:                             395.6
# Df Residuals:                      42   BIC:                             419.4
# Df Model:                          11
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# const                                                     130.0052     12.998     10.002      0.000     103.775     156.236
# student_low_income_percent                                 -0.4397      0.046     -9.498      0.000      -0.533      -0.346
# Total Fruit Servings in cup equivalents                    -5.0384      2.946     -1.710      0.095     -10.983       0.907
# % Calories from SFA.x                                      -3.1446      0.890     -3.534      0.001      -4.940      -1.349
# Beta-Cryptoxanthin (provitamin A carotenoid) (mcg)         -0.0864      0.037     -2.355      0.023      -0.160      -0.012
# Whole Grain Servings in ounce equivalents per 1000 kcal    -9.5417      2.900     -3.291      0.002     -15.393      -3.690
# HEI 2015 Refined Grains (0-10)                             -1.2212      0.936     -1.305      0.199      -3.110       0.668
# 3-Methylhistidine (mg)                                     -0.3783      0.392     -0.965      0.340      -1.169       0.412
# SFA 22:0 (behenic acid) (g)                                16.3443      9.322      1.753      0.087      -2.469      35.157
# Alpha-Carotene (provitamin A carotenoid) (mcg)             -0.0016      0.003     -0.452      0.653      -0.008       0.005
# student_disabilities_percent                               -0.2868      0.348     -0.825      0.414      -0.989       0.415
# Lutein + Zeaxanthin (mcg)                                  -0.0044      0.005     -0.961      0.342      -0.014       0.005
# ==============================================================================
# Omnibus:                        1.774   Durbin-Watson:                   2.368
# Prob(Omnibus):                  0.412   Jarque-Bera (JB):                1.449
# Skew:                          -0.229   Prob(JB):                        0.485
# Kurtosis:                       2.340   Cond. No.                     1.41e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
cv_rmse = -cross_val_score(lasso_model, X_scaled, y, cv=5, scoring='neg_root_mean_squared_error')
cv_mae = -cross_val_score(lasso_model, X_scaled, y, cv=5, scoring='neg_mean_absolute_error')
cv_r2 = cross_val_score(lasso_model, X_scaled, y, cv=5, scoring='r2')

print("CV RMSE mean:", round(cv_rmse.mean(), 4))
print("CV MAE mean:", round(cv_mae.mean(), 4))
print("CV R^2 mean:", round(cv_r2.mean(), 4))
# Out:
# CV RMSE mean: 11.7115
# CV MAE mean: 9.7654
# CV R^2 mean: 0.631
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/ishita/Coder/Proj/STUDENT-MEALS-/venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x=lasso_ols_model.fittedvalues, y=lasso_ols_model.resid)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Residuals vs Fitted")
plt.tight_layout()
plt.show()

# %%
sm.qqplot(lasso_ols_model.resid, line='45', fit=True)
plt.title("QQ Plot of Residuals")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(lasso_ols_model.resid, kde=True)
plt.xlabel("Residuals")
plt.title("Histogram of Residuals")
plt.tight_layout()
plt.show()

# %%
bp_test = het_breuschpagan(lasso_ols_model.resid, lasso_ols_model.model.exog)

bp_results = pd.DataFrame({
    "Statistic": ["LM Statistic", "LM p-value", "F Statistic", "F p-value"],
    "Value": bp_test
})

bp_results
# Out:
#       Statistic      Value
# 0  LM Statistic  15.608093
# 1    LM p-value   0.156315
# 2   F Statistic   1.552268
# 3     F p-value   0.149363

# %%
influence = OLSInfluence(lasso_ols_model)

diagnostics_df = pd.DataFrame({
    "index": df.index,   # use the same dataframe used to fit lasso_ols_model
    "studentized_residual": influence.resid_studentized_external,
    "leverage": influence.hat_matrix_diag,
    "cooks_distance": influence.cooks_distance[0],
    "dffits": influence.dffits[0]
})

diagnostics_df.head()
# Out:
#    index  studentized_residual  leverage  cooks_distance    dffits
# 0      0             -1.755383  0.370410        0.143940 -1.346432
# 1      1              0.881427  0.132461        0.009938  0.344418
# 2      2              0.083990  0.257396        0.000209  0.049448
# 3      3             -0.258602  0.337240        0.002900 -0.184469
# 4      4             -0.840636  0.172195        0.012336 -0.383402

# %%
n = len(diagnostics_df)
p = lasso_ols_model.df_model + 1   # includes intercept

studentized_cutoff = 2
cooks_cutoff = 4 / n
leverage_cutoff = 2 * p / n
dffits_cutoff = 2 * np.sqrt(p / n)

print("Studentized residual cutoff:", round(studentized_cutoff, 4))
print("Cook's distance cutoff:", round(cooks_cutoff, 4))
print("Leverage cutoff:", round(leverage_cutoff, 4))
print("DFFITS cutoff:", round(dffits_cutoff, 4))
# Out:
# Studentized residual cutoff: 2
# Cook's distance cutoff: 0.0741
# Leverage cutoff: 0.4444
# DFFITS cutoff: 0.9428

# %%
diagnostics_df["flag_studentized"] = diagnostics_df["studentized_residual"].abs() > studentized_cutoff
diagnostics_df["flag_cooks"] = diagnostics_df["cooks_distance"] > cooks_cutoff
diagnostics_df["flag_leverage"] = diagnostics_df["leverage"] > leverage_cutoff
diagnostics_df["flag_dffits"] = diagnostics_df["dffits"].abs() > dffits_cutoff

diagnostics_df["n_flags"] = diagnostics_df[
    ["flag_studentized", "flag_cooks", "flag_leverage", "flag_dffits"]
].sum(axis=1)

final_flagged_points = diagnostics_df[diagnostics_df["n_flags"] >= 1].copy()
final_flagged_points.sort_values(["n_flags", "cooks_distance"], ascending=[False, False])
# Out:
#     index  studentized_residual  leverage  cooks_distance    dffits  \
# 48     48             -2.560920  0.331296        0.239121 -1.802551
# 0       0             -1.755383  0.370410        0.143940 -1.346432
# 36     36              1.657847  0.309063        0.098356  1.108789
# 23     23             -1.480061  0.320204        0.083615 -1.015788
# 21     21             -2.059788  0.179439        0.071774 -0.963218
# 14     14              0.384173  0.537824        0.014609  0.414423
# 46     46             -0.135307  0.446009        0.001258 -0.121406
#
#     flag_studentized  flag_cooks  flag_leverage  flag_dffits  n_flags
# 48              True        True          False         True        3
# 0              False        True          False         True        2
# 36             False        True          False         True        2
# 23             False        True          False         True        2
# 21              True       False          False         True        2
# 14             False       False           True        False        1
# 46             False       False           True        False        1

# %%
plt.figure(figsize=(8,5))
plt.stem(diagnostics_df["index"], diagnostics_df["cooks_distance"], basefmt=" ")
plt.axhline(cooks_cutoff, color="red", linestyle="--")
plt.xlabel("Observation index")
plt.ylabel("Cook's distance")
plt.title("Cook's Distance Plot")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x=diagnostics_df["leverage"], y=diagnostics_df["studentized_residual"])
plt.axhline(0, color="red", linestyle="--")
plt.axvline(leverage_cutoff, color="orange", linestyle="--")
plt.xlabel("Leverage")
plt.ylabel("Studentized Residual")
plt.title("Residuals vs Leverage")
plt.tight_layout()
plt.show()

# %%
X_vif = X_ols.drop(columns="const").copy()

vif_df = pd.DataFrame({
    "Predictor": X_vif.columns,
    "VIF": [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]
}).sort_values("VIF", ascending=False)

vif_df
# Out:
#                                             Predictor        VIF
# 9                        student_disabilities_percent  25.834228
# 2                               % Calories from SFA.x  22.833086
# 10                          Lutein + Zeaxanthin (mcg)  13.344038
# 5                      HEI 2015 Refined Grains (0-10)  11.563406
# 1             Total Fruit Servings in cup equivalents   8.899456
# 3   Beta-Cryptoxanthin (provitamin A carotenoid) (...   8.350740
# 6                              3-Methylhistidine (mg)   7.517416
# 8      Alpha-Carotene (provitamin A carotenoid) (mcg)   5.919402
# 0                          student_low_income_percent   4.247914
# 4   Whole Grain Servings in ounce equivalents per ...   3.713268
# 7                         SFA 22:0 (behenic acid) (g)   2.796876

# %% [markdown]
# ### Fitting after handling influential points

# %%
strong_flagged_points = final_flagged_points[final_flagged_points["n_flags"] >= 2]["index"].tolist()

print("Strongly influential points to remove:", strong_flagged_points)

df_refit = df.drop(index=strong_flagged_points).copy()

print("Original shape:", df.shape)
print("Refit shape:", df_refit.shape)
# Out:
# Strongly influential points to remove: [0, 21, 23, 36, 48]
# Original shape: (54, 191)
# Refit shape: (49, 191)

# %%
X_refit = df_refit[selected_predictors].copy()
y_refit = df_refit[target].copy()

X_refit = sm.add_constant(X_refit)
lasso_ols_model_refit = sm.OLS(y_refit, X_refit).fit()

print(lasso_ols_model_refit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Math_Proficiency   R-squared:                       0.908
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     33.11
# Date:                Sun, 26 Apr 2026   Prob (F-statistic):           8.33e-16
# Time:                        02:13:17   Log-Likelihood:                -158.51
# No. Observations:                  49   AIC:                             341.0
# Df Residuals:                      37   BIC:                             363.7
# Df Model:                          11
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# const                                                     123.5064     11.094     11.133      0.000     101.028     145.985
# student_low_income_percent                                 -0.4184      0.043     -9.637      0.000      -0.506      -0.330
# Total Fruit Servings in cup equivalents                    -3.4143      2.583     -1.322      0.194      -8.648       1.819
# % Calories from SFA.x                                      -2.3707      0.789     -3.005      0.005      -3.969      -0.772
# Beta-Cryptoxanthin (provitamin A carotenoid) (mcg)         -0.0664      0.031     -2.124      0.040      -0.130      -0.003
# Whole Grain Servings in ounce equivalents per 1000 kcal    -6.3772      2.642     -2.414      0.021     -11.730      -1.024
# HEI 2015 Refined Grains (0-10)                             -1.1900      0.807     -1.474      0.149      -2.826       0.446
# 3-Methylhistidine (mg)                                     -0.5094      0.332     -1.533      0.134      -1.182       0.164
# SFA 22:0 (behenic acid) (g)                                21.9734      8.534      2.575      0.014       4.682      39.265
# Alpha-Carotene (provitamin A carotenoid) (mcg)             -0.0080      0.003     -2.394      0.022      -0.015      -0.001
# student_disabilities_percent                               -0.4916      0.364     -1.351      0.185      -1.229       0.246
# Lutein + Zeaxanthin (mcg)                                  -0.0032      0.004     -0.811      0.423      -0.011       0.005
# ==============================================================================
# Omnibus:                        0.932   Durbin-Watson:                   2.308
# Prob(Omnibus):                  0.628   Jarque-Bera (JB):                0.745
# Skew:                          -0.297   Prob(JB):                        0.689
# Kurtosis:                       2.892   Cond. No.                     1.41e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
comparison_df = pd.DataFrame({
    "Metric": ["R-squared", "Adj R-squared", "AIC", "BIC", "RMSE"],
    "Original": [
        lasso_ols_model.rsquared,
        lasso_ols_model.rsquared_adj,
        lasso_ols_model.aic,
        lasso_ols_model.bic,
        np.sqrt(np.mean(lasso_ols_model.resid**2))
    ],
    "Refit": [
        lasso_ols_model_refit.rsquared,
        lasso_ols_model_refit.rsquared_adj,
        lasso_ols_model_refit.aic,
        lasso_ols_model_refit.bic,
        np.sqrt(np.mean(lasso_ols_model_refit.resid**2))
    ]
})

comparison_df
# Out:
#           Metric    Original       Refit
# 0      R-squared    0.856346    0.907787
# 1  Adj R-squared    0.818722    0.880372
# 2            AIC  395.565814  341.024206
# 3            BIC  419.433623  363.726050
# 4           RMSE    7.549533    6.147235

# %%
fitted_vals_refit = lasso_ols_model_refit.fittedvalues
residuals_refit = lasso_ols_model_refit.resid

# Residuals vs Fitted
plt.figure(figsize=(7,5))
sns.scatterplot(x=fitted_vals_refit, y=residuals_refit)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Refit Model: Residuals vs Fitted")
plt.tight_layout()
plt.show()

# QQ Plot
sm.qqplot(residuals_refit, line='45', fit=True)
plt.title("Refit Model: QQ Plot")
plt.tight_layout()
plt.show()

# Histogram
plt.figure(figsize=(7,5))
sns.histplot(residuals_refit, kde=True)
plt.xlabel("Residuals")
plt.title("Refit Model: Histogram of Residuals")
plt.tight_layout()
plt.show()

# Scale-Location Plot
influence_refit = lasso_ols_model_refit.get_influence()
std_resid_refit = influence_refit.resid_studentized_internal
sqrt_abs_std_resid_refit = np.sqrt(np.abs(std_resid_refit))

plt.figure(figsize=(7,5))
sns.scatterplot(x=fitted_vals_refit, y=sqrt_abs_std_resid_refit)
plt.xlabel("Fitted values")
plt.ylabel("Sqrt(|Standardized residuals|)")
plt.title("Refit Model: Scale-Location Plot")
plt.tight_layout()
plt.show()

# %%
bp_test_refit = het_breuschpagan(
    lasso_ols_model_refit.resid,
    lasso_ols_model_refit.model.exog
)

bp_results_refit = pd.DataFrame({
    "Statistic": ["LM Statistic", "LM p-value", "F Statistic", "F p-value"],
    "Value": bp_test_refit
})

bp_results_refit
# Out:
#       Statistic      Value
# 0  LM Statistic  16.628477
# 1    LM p-value   0.119356
# 2   F Statistic   1.727820
# 3     F p-value   0.105233

# %%
influence_refit = OLSInfluence(lasso_ols_model_refit)

diagnostics_refit = pd.DataFrame({
    "index": df_refit.index,
    "studentized_residual": influence_refit.resid_studentized_external,
    "leverage": influence_refit.hat_matrix_diag,
    "cooks_distance": influence_refit.cooks_distance[0],
    "dffits": influence_refit.dffits[0]
})

n_refit = len(diagnostics_refit)
p_refit = lasso_ols_model_refit.df_model + 1

studentized_cutoff_refit = 2
cooks_cutoff_refit = 4 / n_refit
leverage_cutoff_refit = 2 * p_refit / n_refit
dffits_cutoff_refit = 2 * np.sqrt(p_refit / n_refit)

diagnostics_refit["flag_studentized"] = diagnostics_refit["studentized_residual"].abs() > studentized_cutoff_refit
diagnostics_refit["flag_cooks"] = diagnostics_refit["cooks_distance"] > cooks_cutoff_refit
diagnostics_refit["flag_leverage"] = diagnostics_refit["leverage"] > leverage_cutoff_refit
diagnostics_refit["flag_dffits"] = diagnostics_refit["dffits"].abs() > dffits_cutoff_refit

diagnostics_refit["n_flags"] = diagnostics_refit[
    ["flag_studentized", "flag_cooks", "flag_leverage", "flag_dffits"]
].sum(axis=1)

final_flagged_refit = diagnostics_refit[diagnostics_refit["n_flags"] >= 1].copy()
final_flagged_refit.sort_values(["n_flags", "cooks_distance"], ascending=[False, False])
# Out:
#     index  studentized_residual  leverage  cooks_distance    dffits  \
# 27     27             -2.909270  0.182605        0.131118 -1.375069
# 17     17              2.104417  0.231348        0.101656  1.154515
# 47     47             -1.924386  0.321234        0.136107 -1.323862
# 46     46             -0.280348  0.525502        0.007439 -0.295031
# 6       6             -0.135682  0.542303        0.001867 -0.147691
# 14     14              0.109817  0.558363        0.001305  0.123480
#
#     flag_studentized  flag_cooks  flag_leverage  flag_dffits  n_flags
# 27              True        True          False         True        3
# 17              True        True          False         True        3
# 47             False        True          False         True        2
# 46             False       False           True        False        1
# 6              False       False           True        False        1
# 14             False       False           True        False        1

# %%
plt.figure(figsize=(8,5))
plt.stem(diagnostics_refit["index"], diagnostics_refit["cooks_distance"], basefmt=" ")
plt.axhline(cooks_cutoff_refit, color="red", linestyle="--")
plt.xlabel("Observation index")
plt.ylabel("Cook's distance")
plt.title("Refit Model: Cook's Distance Plot")
plt.tight_layout()
plt.show()

plt.figure(figsize=(7,5))
sns.scatterplot(x=diagnostics_refit["leverage"], y=diagnostics_refit["studentized_residual"])
plt.axhline(0, color="red", linestyle="--")
plt.axvline(leverage_cutoff_refit, color="orange", linestyle="--")
plt.xlabel("Leverage")
plt.ylabel("Studentized Residual")
plt.title("Refit Model: Residuals vs Leverage")
plt.tight_layout()
plt.show()

# %%
X_vif_refit = X_refit.drop(columns="const").copy()

vif_refit_df = pd.DataFrame({
    "Predictor": X_vif_refit.columns,
    "VIF": [variance_inflation_factor(X_vif_refit.values, i) for i in range(X_vif_refit.shape[1])]
}).sort_values("VIF", ascending=False)

vif_refit_df
# Out:
#                                             Predictor        VIF
# 9                        student_disabilities_percent  38.003135
# 2                               % Calories from SFA.x  27.727438
# 10                          Lutein + Zeaxanthin (mcg)  13.430528
# 5                      HEI 2015 Refined Grains (0-10)  11.529779
# 1             Total Fruit Servings in cup equivalents   8.785547
# 3   Beta-Cryptoxanthin (provitamin A carotenoid) (...   8.313043
# 8      Alpha-Carotene (provitamin A carotenoid) (mcg)   7.350444
# 6                              3-Methylhistidine (mg)   7.319004
# 0                          student_low_income_percent   5.202374
# 4   Whole Grain Servings in ounce equivalents per ...   4.054877
# 7                         SFA 22:0 (behenic acid) (g)   2.928426

# %%
def calculate_vif(X):
    vif_df = pd.DataFrame({
        "Predictor": X.columns,
        "VIF": [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    })
    return vif_df.sort_values("VIF", ascending=False)

X_vif_refine = X_refit.drop(columns="const").copy()

threshold = 10

while True:
    vif_df = calculate_vif(X_vif_refine)
    max_vif = vif_df["VIF"].max()
    
    if max_vif <= threshold:
        break
    
    remove_var = vif_df.iloc[0]["Predictor"]
    print(f"Removing {remove_var} with VIF = {max_vif:.2f}")
    
    X_vif_refine = X_vif_refine.drop(columns=[remove_var])

print("\nFinal predictors after VIF filtering:")
print(X_vif_refine.columns)
# Out:
# Removing student_disabilities_percent with VIF = 38.00
# Removing Lutein + Zeaxanthin (mcg) with VIF = 13.20
# Removing HEI 2015 Refined Grains (0-10) with VIF = 10.45
#
# Final predictors after VIF filtering:
# Index(['student_low_income_percent', 'Total Fruit Servings in cup equivalents',
#        '% Calories from SFA.x',
#        'Beta-Cryptoxanthin (provitamin A carotenoid) (mcg)',
#        'Whole Grain Servings in ounce equivalents per 1000 kcal',
#        '3-Methylhistidine (mg)', 'SFA 22:0 (behenic acid) (g)',
#        'Alpha-Carotene (provitamin A carotenoid) (mcg)'],
#       dtype='object')

# %%
X_final = sm.add_constant(X_vif_refine)
y_final = y_refit.copy()

final_model = sm.OLS(y_final, X_final).fit()

print(final_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Math_Proficiency   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.873
# Method:                 Least Squares   F-statistic:                     42.08
# Date:                Sun, 26 Apr 2026   Prob (F-statistic):           4.28e-17
# Time:                        02:13:18   Log-Likelihood:                -161.97
# No. Observations:                  49   AIC:                             341.9
# Df Residuals:                      40   BIC:                             359.0
# Df Model:                           8
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# const                                                     110.1187      9.550     11.530      0.000      90.817     129.421
# student_low_income_percent                                 -0.4550      0.041    -11.206      0.000      -0.537      -0.373
# Total Fruit Servings in cup equivalents                    -5.5210      2.316     -2.384      0.022     -10.201      -0.841
# % Calories from SFA.x                                      -2.2493      0.770     -2.921      0.006      -3.806      -0.693
# Beta-Cryptoxanthin (provitamin A carotenoid) (mcg)         -0.0726      0.032     -2.297      0.027      -0.137      -0.009
# Whole Grain Servings in ounce equivalents per 1000 kcal    -7.1769      2.562     -2.801      0.008     -12.356      -1.998
# 3-Methylhistidine (mg)                                     -0.3829      0.315     -1.215      0.231      -1.020       0.254
# SFA 22:0 (behenic acid) (g)                                20.7845      7.752      2.681      0.011       5.117      36.452
# Alpha-Carotene (provitamin A carotenoid) (mcg)             -0.0087      0.003     -2.883      0.006      -0.015      -0.003
# ==============================================================================
# Omnibus:                        0.604   Durbin-Watson:                   2.375
# Prob(Omnibus):                  0.739   Jarque-Bera (JB):                0.385
# Skew:                          -0.217   Prob(JB):                        0.825
# Kurtosis:                       2.964   Cond. No.                     8.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
final_vif = calculate_vif(X_vif_refine)
final_vif
# Out:
#                                            Predictor       VIF
# 2                              % Calories from SFA.x  8.005395
# 3  Beta-Cryptoxanthin (provitamin A carotenoid) (...  7.498488
# 1            Total Fruit Servings in cup equivalents  6.658696
# 7     Alpha-Carotene (provitamin A carotenoid) (mcg)  5.738864
# 5                             3-Methylhistidine (mg)  5.664844
# 0                         student_low_income_percent  4.161567
# 4  Whole Grain Servings in ounce equivalents per ...  3.412556
# 6                        SFA 22:0 (behenic acid) (g)  2.242597

# %%
final_fitted = final_model.fittedvalues
final_residuals = final_model.resid

print("Mean of residuals:", final_residuals.mean())
print("RMSE:", np.sqrt(np.mean(final_residuals**2)))
# Out:
# Mean of residuals: 3.552713678800501e-15
# RMSE: 6.596955216179712

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x=final_fitted, y=final_residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Final Model: Residuals vs Fitted")
plt.tight_layout()
plt.show()

# %%
sm.qqplot(final_residuals, line='45', fit=True)
plt.title("Final Model: QQ Plot")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(final_residuals, kde=True)
plt.xlabel("Residuals")
plt.title("Final Model: Histogram of Residuals")
plt.tight_layout()
plt.show()

# %%
final_influence = final_model.get_influence()
final_std_resid = final_influence.resid_studentized_internal
sqrt_abs_final_std_resid = np.sqrt(np.abs(final_std_resid))

plt.figure(figsize=(7,5))
sns.scatterplot(x=final_fitted, y=sqrt_abs_final_std_resid)
plt.xlabel("Fitted values")
plt.ylabel("Sqrt(|Standardized residuals|)")
plt.title("Final Model: Scale-Location Plot")
plt.tight_layout()
plt.show()

# %%
bp_test_final = het_breuschpagan(
    final_model.resid,
    final_model.model.exog
)

bp_results_final = pd.DataFrame({
    "Statistic": ["LM Statistic", "LM p-value", "F Statistic", "F p-value"],
    "Value": bp_test_final
})

bp_results_final
# Out:
#       Statistic      Value
# 0  LM Statistic  15.443636
# 1    LM p-value   0.051072
# 2   F Statistic   2.301149
# 3     F p-value   0.039314

# %%
from scipy.stats import shapiro

shapiro_stat, shapiro_p = shapiro(final_residuals)

print("Shapiro-Wilk Statistic:", shapiro_stat)
print("Shapiro-Wilk p-value:", shapiro_p)
# Out:
# Shapiro-Wilk Statistic: 0.9905722879469165
# Shapiro-Wilk p-value: 0.9613286298531327

# %% [markdown]
# Residual diagnostics for the final model indicated mild heteroscedasticity based on the Breusch–Pagan test. Therefore, HC3 robust standard errors were used to obtain more reliable inference.

# %%
# HC3 robust standard errors
final_model_robust = final_model.get_robustcov_results(cov_type='HC3')
print(final_model_robust.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Math_Proficiency   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.873
# Method:                 Least Squares   F-statistic:                     50.55
# Date:                Sun, 26 Apr 2026   Prob (F-statistic):           1.65e-18
# Time:                        02:13:18   Log-Likelihood:                -161.97
# No. Observations:                  49   AIC:                             341.9
# Df Residuals:                      40   BIC:                             359.0
# Df Model:                           8
# Covariance Type:                  HC3
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# const                                                     110.1187     10.390     10.598      0.000      89.119     131.118
# student_low_income_percent                                 -0.4550      0.043    -10.645      0.000      -0.541      -0.369
# Total Fruit Servings in cup equivalents                    -5.5210      3.183     -1.735      0.091     -11.954       0.912
# % Calories from SFA.x                                      -2.2493      0.755     -2.980      0.005      -3.775      -0.724
# Beta-Cryptoxanthin (provitamin A carotenoid) (mcg)         -0.0726      0.030     -2.403      0.021      -0.134      -0.012
# Whole Grain Servings in ounce equivalents per 1000 kcal    -7.1769      2.495     -2.877      0.006     -12.219      -2.135
# 3-Methylhistidine (mg)                                     -0.3829      0.331     -1.158      0.254      -1.051       0.285
# SFA 22:0 (behenic acid) (g)                                20.7845      8.000      2.598      0.013       4.615      36.954
# Alpha-Carotene (provitamin A carotenoid) (mcg)             -0.0087      0.003     -2.588      0.013      -0.016      -0.002
# ==============================================================================
# Omnibus:                        0.604   Durbin-Watson:                   2.375
# Prob(Omnibus):                  0.739   Jarque-Bera (JB):                0.385
# Skew:                          -0.217   Prob(JB):                        0.825
# Kurtosis:                       2.964   Cond. No.                     8.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 8.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Fitting model again after removing high VIF variables
